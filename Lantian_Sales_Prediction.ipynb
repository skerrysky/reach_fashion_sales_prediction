# %% [markdown]
# ## Project: Predicting Fashion Sales Quantity based Data from Past Three Months
#
# #### I completed a solo project that uses fashion product online transaction data to predict sales quantity. I used feature engineering and deployed the XGBoost model to make the prediction. There are two major challenges: 1) extract features from training data and relevant tables; 2) set appropriate XGBoost parameters for good model performance.
#
# ### Case Scenario:
#
# ##### A French e-commerce company has gathered a large amount of data on its fashion products’ online transactions from the last quarter. The fashion products include two types: leather goods and accessories. It is trying to increase marketing investment and achieve a high ROI in the next quarter. To optimize the investment strategy, it wants to utilize the data to effectively predict sales quantity.

# %%
import os.path
import pandas as pd
import numpy as np
import xgboost as xgb

base_path = "./data/"

# %% [markdown]
# ### Data Description
# #### Read data and go over each csv file

# %%
navigation = pd.read_csv(os.path.join(base_path, 'navigation.csv'))
sales = pd.read_csv(os.path.join(base_path, 'sales.csv'))
train = pd.read_csv(os.path.join(base_path, 'train.csv'))
test = pd.read_csv(os.path.join(base_path, 'test.csv'))

# %%
train.head()
# Out:
#                                            ID  month  \
# 0  3d8a4ae769b526187c36901f204691a663333fa4_1      1
# 1  c05a54f7067be054ec4b27d0d6081353ef7d9df6_1      1
# 2  7cb4d3626bd48a9b523d8693266219c34aeccde8_1      1
# 3  8e5967f90ff9fb93aa2840fceecc537b2e8e6ff3_1      1
# 4  6913a128945e0efeafc52101dcdeaa610eaa4430_1      1
#
#                                    sku_hash   product_type product_gender  \
# 0  3d8a4ae769b526187c36901f204691a663333fa4  Leather Goods          Women
# 1  c05a54f7067be054ec4b27d0d6081353ef7d9df6    Accessories          Women
# 2  7cb4d3626bd48a9b523d8693266219c34aeccde8  Leather Goods          Women
# 3  8e5967f90ff9fb93aa2840fceecc537b2e8e6ff3  Leather Goods          Women
# 4  6913a128945e0efeafc52101dcdeaa610eaa4430    Accessories            Men
#
#       macro_function             function     sub_function  \
# 0     LG ACCESSORIES  SMALL LEATHER GOODS  COMPACT WALLETS
# 1  FANCY ACCESSORIES           BAG CHARMS       BAG CHARMS
# 2          CITY BAGS           DAILY BAGS    SHOULDER BAGS
# 3          CITY BAGS           DAILY BAGS    SHOULDER BAGS
# 4    FASHION JEWELRY            NECKLACES        NECKLACES
#
#                        model     aesthetic_sub_line      macro_material  \
# 0               PF.VICTORINE            DAMIER AZUR              CANVAS
# 1     BAG CHARM PETITE MALLE  SANS LIGNE ESTHETIQUE              CANVAS
# 2                   GIROLATA                 MAHINA             LEATHER
# 3                   GIROLATA                 MAHINA             LEATHER
# 4  COLL.CHARMS FOR GENTLEMEN  SANS LIGNE ESTHETIQUE  NON PRECIOUS METAL
#
#       color  fr_FR_price                                  en_US_description  \
# 0      AZUR        370.0  Fashioned from summery Damier Azur canvas, thi...
# 1       NaN        295.0  This collectible piece features our iconic Pet...
# 2     GALET       2660.0  The perfect summer companion, this effortlessl...
# 3  MAGNOLIA       2660.0  The perfect summer companion, this effortlessl...
# 4       NaN        325.0  This distinctive charm necklace reinterprets d...
#
#    target
# 0  1366.0
# 1   526.0
# 2   503.0
# 3   276.0
# 4   206.0

# %%
train.shape
# Out:
# (5298, 15)

# %%
sales.head()
# Out:
#     Date day_transaction_date  Month_transaction    type  zone_number  \
# 0  Day_7             Thursday                  4  Type_2            4
# 1  Day_6            Wednesday                  4  Type_1            4
# 2  Day_1               Monday                  1  Type_2            2
# 3  Day_7               Sunday                  1  Type_1            3
# 4  Day_5              Tuesday                  2  Type_1            4
#
#    country_number    name                                  sku_hash  \
# 0              43  Name_1  84d4e90b67c2b9902cff522be4eb121f637c17b5
# 1              20  Name_1  84d4e90b67c2b9902cff522be4eb121f637c17b5
# 2              65  Name_1  70f3dd559074ecfc9d69ff64480bc8acae977e3a
# 3              49  Name_1  70f3dd559074ecfc9d69ff64480bc8acae977e3a
# 4              20  Name_1  1f8b7a2b42d4cdf5eef70f75fb86a34d514d2747
#
#    sales_quantity  currency_rate_USD  ...  NetSentiment_6_day_before  \
# 0               5           1.225636  ...                  77.525599
# 1               5           1.228951  ...                  70.473656
# 2               5           1.201496  ...                  46.158532
# 3               5           1.204091  ...                  72.438611
# 4               5           1.238391  ...                  72.776593
#
#    PositiveSentiment_6_day_before  NegativeSentiment_6_day_before  \
# 0                         33634.0                          4258.0
# 1                         32032.0                          5548.0
# 2                         27594.0                         10165.0
# 3                         16292.0                          2604.0
# 4                         28344.0                          4466.0
#
#    Impressions_6_day_before  TotalBuzzPost_7_day_before  \
# 0               643226023.0                     68960.0
# 1               631477319.0                     65312.0
# 2               359205211.0                     45746.0
# 3               307167067.0                     42796.0
# 4               440849942.0                     60653.0
#
#    TotalBuzz_7_day_before  NetSentiment_7_day_before  \
# 0                107970.0                  70.473656
# 1                102920.0                  71.788703
# 2                 64881.0                  73.083627
# 3                 61653.0                  68.744442
# 4                 90848.0                  75.338753
#
#    PositiveSentiment_7_day_before  NegativeSentiment_7_day_before  \
# 0                         32032.0                          5548.0
# 1                         34277.0                          5629.0
# 2                         21349.0                          3320.0
# 3                         20872.0                          3866.0
# 4                         26527.0                          3731.0
#
#    Impressions_7_day_before
# 0               631477319.0
# 1               730132649.0
# 2               268925766.0
# 3               323820589.0
# 4               393463263.0
#
# [5 rows x 97 columns]

# %%
sales.shape
# Out:
# (145135, 97)

# %%
navigation.head()
# Out:
#     Date                                  sku_hash  day_visit  month_visit  \
# 0  Day 6  b6cb56a971c9ffeeaf1833202ab453b51ab680a9  Wednesday            9
# 1  Day 4  9c5060f9fb648cdfafd66f170af517f4de0a9162     Monday            9
# 2  Day 4  da1549af83c813e5b53a4e4c0d588fa0099e3d3d     Monday           10
# 3  Day 6  477ac04baf2a484f441ffe688abc89bb46a1c21d  Wednesday           10
# 4  Day 4  799bd8691fe0be0137173eadd5e79d033a389bd8     Monday           10
#
#    website_version_zone_number  website_version_country_number traffic_source  \
# 0                          5.0                            32.0       Source 1
# 1                          5.0                            32.0       Source 1
# 2                          5.0                            32.0       Source 1
# 3                          5.0                            32.0       Source 1
# 4                          5.0                            32.0       Source 2
#
#    page_views  addtocart
# 0         105          0
# 1         314          0
# 2          57          0
# 3         547          0
# 4          43          0

# %%
navigation.shape
# Out:
# (261399, 9)

# %%
test.head()
# Out:
#                                            ID  month  \
# 0  ed4c7471eac7e8c6e6718364c2b6e75462eeb47c_1      1
# 1  26b2c4f6281482cccf1e748ef388f1649ecf1c8b_1      1
# 2  00aad36ebc04aaa761df219c1b48d1e6162d28bb_1      1
# 3  8281636e7d162c92c1a3c1f9e40afb05d39a02f9_1      1
# 4  b76f8505700409a198fe69fb33e5d6cc01166c9b_1      1
#
#                                    sku_hash   product_type product_gender  \
# 0  ed4c7471eac7e8c6e6718364c2b6e75462eeb47c    Accessories          Women
# 1  26b2c4f6281482cccf1e748ef388f1649ecf1c8b  Leather Goods          Women
# 2  00aad36ebc04aaa761df219c1b48d1e6162d28bb  Leather Goods          Women
# 3  8281636e7d162c92c1a3c1f9e40afb05d39a02f9    Accessories            Men
# 4  b76f8505700409a198fe69fb33e5d6cc01166c9b    Accessories            Men
#
#   macro_function    function         sub_function                      model  \
# 0       TEXTILES     SCARVES       WINTER SCARVES          ECHARPE REYKJAVIK
# 1      CITY BAGS  DAILY BAGS             HANDBAGS           VERY ZIPPED TOTE
# 2      CITY BAGS  DAILY BAGS  CROSS SHOULDER BAGS                       HINA
# 3       TEXTILES      STOLES        WINTER STOLES   ETOLE MONOGRAM NIGHTFALL
# 4           TIES        TIES           OTHER TIES  CRAVATE MONOGRAM ILLUSION
#
#       aesthetic_sub_line macro_material                color  fr_FR_price  \
# 0  SANS LIGNE ESTHETIQUE        TEXTILE                  NaN        650.0
# 1                   VERY        LEATHER  KAKI FANGO COQUILLE       2550.0
# 2                 MAHINA        LEATHER                 NOIR       2460.0
# 3  SANS LIGNE ESTHETIQUE        TEXTILE                  NaN        455.0
# 4  SANS LIGNE ESTHETIQUE        TEXTILE                  NaN        150.0
#
#                                    en_US_description
# 0  In pure, soft cashmere, the Reykjavik scarf is...
# 1  For Fall-Winter 2018, the Very Zipped Tote han...
# 2  The Hina is two bags in one: gather in the sid...
# 3  With its subtle tone-on-tone Monogram pattern ...
# 4  Suitable both for business and special occasio...

# %%
test.shape
# Out:
# (5166, 14)

# %% [markdown]
# ### Feature Engineering:
#
# #### Extract important features
# #### 1) Extract features in training and test data sets:

# %% [markdown]
# ##### a) Obtain mean target sales quantity for products of different colors (group by other attributes), and merge this mean_target to training and test data

# %%
product_descriptor = ['product_type', 'product_gender', 'macro_function', 
                      'function', 'sub_function', 'model', 'aesthetic_sub_line', 'macro_material',
                      'month']
product_target_sum = train.groupby(product_descriptor)['target'].sum().reset_index(name = 'sum_target')
product_target_count = train.groupby(product_descriptor)['target'].count().reset_index(name = 'count_target')
product_target_stats = pd.merge(product_target_sum,product_target_count,on=product_descriptor)

train = train.merge(product_target_stats,on=product_descriptor,how='left')
test = test.merge(product_target_stats,on=product_descriptor,how='left')

train['mean_target'] = (train['sum_target'] - train['target'])/(train['count_target']-1)
test['mean_target'] = test['sum_target']/test['count_target']

# %%
train.head()
# Out:
#                                            ID  month  \
# 0  3d8a4ae769b526187c36901f204691a663333fa4_1      1
# 1  c05a54f7067be054ec4b27d0d6081353ef7d9df6_1      1
# 2  7cb4d3626bd48a9b523d8693266219c34aeccde8_1      1
# 3  8e5967f90ff9fb93aa2840fceecc537b2e8e6ff3_1      1
# 4  6913a128945e0efeafc52101dcdeaa610eaa4430_1      1
#
#                                    sku_hash   product_type product_gender  \
# 0  3d8a4ae769b526187c36901f204691a663333fa4  Leather Goods          Women
# 1  c05a54f7067be054ec4b27d0d6081353ef7d9df6    Accessories          Women
# 2  7cb4d3626bd48a9b523d8693266219c34aeccde8  Leather Goods          Women
# 3  8e5967f90ff9fb93aa2840fceecc537b2e8e6ff3  Leather Goods          Women
# 4  6913a128945e0efeafc52101dcdeaa610eaa4430    Accessories            Men
#
#       macro_function             function     sub_function  \
# 0     LG ACCESSORIES  SMALL LEATHER GOODS  COMPACT WALLETS
# 1  FANCY ACCESSORIES           BAG CHARMS       BAG CHARMS
# 2          CITY BAGS           DAILY BAGS    SHOULDER BAGS
# 3          CITY BAGS           DAILY BAGS    SHOULDER BAGS
# 4    FASHION JEWELRY            NECKLACES        NECKLACES
#
#                        model     aesthetic_sub_line      macro_material  \
# 0               PF.VICTORINE            DAMIER AZUR              CANVAS
# 1     BAG CHARM PETITE MALLE  SANS LIGNE ESTHETIQUE              CANVAS
# 2                   GIROLATA                 MAHINA             LEATHER
# 3                   GIROLATA                 MAHINA             LEATHER
# 4  COLL.CHARMS FOR GENTLEMEN  SANS LIGNE ESTHETIQUE  NON PRECIOUS METAL
#
#       color  fr_FR_price                                  en_US_description  \
# 0      AZUR        370.0  Fashioned from summery Damier Azur canvas, thi...
# 1       NaN        295.0  This collectible piece features our iconic Pet...
# 2     GALET       2660.0  The perfect summer companion, this effortlessl...
# 3  MAGNOLIA       2660.0  The perfect summer companion, this effortlessl...
# 4       NaN        325.0  This distinctive charm necklace reinterprets d...
#
#    target  sum_target  count_target  mean_target
# 0  1366.0      1837.0             2   471.000000
# 1   526.0       526.0             1          NaN
# 2   503.0      1395.0             4   297.333333
# 3   276.0      1395.0             4   373.000000
# 4   206.0       206.0             1          NaN

# %%
train.drop(['count_target','sum_target'],axis=1, inplace = True) 
test.drop(['count_target','sum_target'],axis=1, inplace = True)

# %%
train.head()
# Out:
#                                            ID  month  \
# 0  3d8a4ae769b526187c36901f204691a663333fa4_1      1
# 1  c05a54f7067be054ec4b27d0d6081353ef7d9df6_1      1
# 2  7cb4d3626bd48a9b523d8693266219c34aeccde8_1      1
# 3  8e5967f90ff9fb93aa2840fceecc537b2e8e6ff3_1      1
# 4  6913a128945e0efeafc52101dcdeaa610eaa4430_1      1
#
#                                    sku_hash   product_type product_gender  \
# 0  3d8a4ae769b526187c36901f204691a663333fa4  Leather Goods          Women
# 1  c05a54f7067be054ec4b27d0d6081353ef7d9df6    Accessories          Women
# 2  7cb4d3626bd48a9b523d8693266219c34aeccde8  Leather Goods          Women
# 3  8e5967f90ff9fb93aa2840fceecc537b2e8e6ff3  Leather Goods          Women
# 4  6913a128945e0efeafc52101dcdeaa610eaa4430    Accessories            Men
#
#       macro_function             function     sub_function  \
# 0     LG ACCESSORIES  SMALL LEATHER GOODS  COMPACT WALLETS
# 1  FANCY ACCESSORIES           BAG CHARMS       BAG CHARMS
# 2          CITY BAGS           DAILY BAGS    SHOULDER BAGS
# 3          CITY BAGS           DAILY BAGS    SHOULDER BAGS
# 4    FASHION JEWELRY            NECKLACES        NECKLACES
#
#                        model     aesthetic_sub_line      macro_material  \
# 0               PF.VICTORINE            DAMIER AZUR              CANVAS
# 1     BAG CHARM PETITE MALLE  SANS LIGNE ESTHETIQUE              CANVAS
# 2                   GIROLATA                 MAHINA             LEATHER
# 3                   GIROLATA                 MAHINA             LEATHER
# 4  COLL.CHARMS FOR GENTLEMEN  SANS LIGNE ESTHETIQUE  NON PRECIOUS METAL
#
#       color  fr_FR_price                                  en_US_description  \
# 0      AZUR        370.0  Fashioned from summery Damier Azur canvas, thi...
# 1       NaN        295.0  This collectible piece features our iconic Pet...
# 2     GALET       2660.0  The perfect summer companion, this effortlessl...
# 3  MAGNOLIA       2660.0  The perfect summer companion, this effortlessl...
# 4       NaN        325.0  This distinctive charm necklace reinterprets d...
#
#    target  mean_target
# 0  1366.0   471.000000
# 1   526.0          NaN
# 2   503.0   297.333333
# 3   276.0   373.000000
# 4   206.0          NaN

# %% [markdown]
# ##### b) Count the number of products of identical attributes (product function, model name, material, color), and merge these counts to training and test data

# %%
count_vec_cols = ['macro_function', 'function', 'sub_function', 'model',
                  'aesthetic_sub_line', 'macro_material', 'color']

for col in count_vec_cols:
    tmp = pd.DataFrame({'sku_hash':pd.concat([train['sku_hash'],test['sku_hash']]),col:pd.concat([train[col],test[col]])})
    tmp = pd.DataFrame(tmp.groupby(col)['sku_hash'].count()).reset_index()
    tmp.columns = [col,col+'_count']
    
    train = train.merge(tmp,on=col,how='left')
    test = test.merge(tmp,on=col,how='left')

# %%
train.head()
# Out:
#                                            ID  month  \
# 0  3d8a4ae769b526187c36901f204691a663333fa4_1      1
# 1  c05a54f7067be054ec4b27d0d6081353ef7d9df6_1      1
# 2  7cb4d3626bd48a9b523d8693266219c34aeccde8_1      1
# 3  8e5967f90ff9fb93aa2840fceecc537b2e8e6ff3_1      1
# 4  6913a128945e0efeafc52101dcdeaa610eaa4430_1      1
#
#                                    sku_hash   product_type product_gender  \
# 0  3d8a4ae769b526187c36901f204691a663333fa4  Leather Goods          Women
# 1  c05a54f7067be054ec4b27d0d6081353ef7d9df6    Accessories          Women
# 2  7cb4d3626bd48a9b523d8693266219c34aeccde8  Leather Goods          Women
# 3  8e5967f90ff9fb93aa2840fceecc537b2e8e6ff3  Leather Goods          Women
# 4  6913a128945e0efeafc52101dcdeaa610eaa4430    Accessories            Men
#
#       macro_function             function     sub_function  \
# 0     LG ACCESSORIES  SMALL LEATHER GOODS  COMPACT WALLETS
# 1  FANCY ACCESSORIES           BAG CHARMS       BAG CHARMS
# 2          CITY BAGS           DAILY BAGS    SHOULDER BAGS
# 3          CITY BAGS           DAILY BAGS    SHOULDER BAGS
# 4    FASHION JEWELRY            NECKLACES        NECKLACES
#
#                        model     aesthetic_sub_line  ...  \
# 0               PF.VICTORINE            DAMIER AZUR  ...
# 1     BAG CHARM PETITE MALLE  SANS LIGNE ESTHETIQUE  ...
# 2                   GIROLATA                 MAHINA  ...
# 3                   GIROLATA                 MAHINA  ...
# 4  COLL.CHARMS FOR GENTLEMEN  SANS LIGNE ESTHETIQUE  ...
#
#                                    en_US_description  target  mean_target  \
# 0  Fashioned from summery Damier Azur canvas, thi...  1366.0   471.000000
# 1  This collectible piece features our iconic Pet...   526.0          NaN
# 2  The perfect summer companion, this effortlessl...   503.0   297.333333
# 3  The perfect summer companion, this effortlessl...   276.0   373.000000
# 4  This distinctive charm necklace reinterprets d...   206.0          NaN
#
#   macro_function_count  function_count  sub_function_count  model_count  \
# 0                 2292            2094                 447           90
# 1                  546             126                 102            3
# 2                 3039            2784                 699           15
# 3                 3039            2784                 699           15
# 4                  843             171                 162            3
#
#    aesthetic_sub_line_count  macro_material_count  color_count
# 0                       126                  3213        120.0
# 1                      3477                  3213          NaN
# 2                        90                  4089         39.0
# 3                        90                  4089         60.0
# 4                      3477                  1023          NaN
#
# [5 rows x 23 columns]

# %% [markdown]
# #### 2) Extract features in navigation and sales data sets:

# %% [markdown]
# ##### a) Summarize page views for products of different traffic sources (e.g., email, natural search, etc. total of 6 different sources)

# %%
traffic_source_views = navigation.groupby(['sku_hash','traffic_source'])['page_views'].sum().reset_index()

# %%
traffic_source_views[:5]
# Out:
#                                    sku_hash traffic_source  page_views
# 0  000cb631113e2f54ca5512139a6592e9584957aa       Source 1        1748
# 1  000cb631113e2f54ca5512139a6592e9584957aa       Source 2          40
# 2  000cb631113e2f54ca5512139a6592e9584957aa       Source 5          30
# 3  000cb631113e2f54ca5512139a6592e9584957aa       Source 6          48
# 4  0020d561eab8b88ab55dfde84a2f12b865e5e0b4       Source 1       16300

# %%
traffic_source_views = traffic_source_views.pivot(index = 'sku_hash',columns = 'traffic_source',values = 'page_views').reset_index()

# %%
traffic_source_views.columns = ['sku_hash', 
                                'page_views_nav1', 'page_views_nav2', 'page_views_nav3', 
                                'page_views_nav4', 'page_views_nav5', 'page_views_nav6']

# %%
traffic_source_views.head()
# Out:
#                                    sku_hash  page_views_nav1  page_views_nav2  \
# 0  000cb631113e2f54ca5512139a6592e9584957aa           1748.0             40.0
# 1  0020d561eab8b88ab55dfde84a2f12b865e5e0b4          16300.0            286.0
# 2  0026e7a0fcfe5999a44b70b1acaff00fc1ad3ac2            147.0              5.0
# 3  00287bbb94c12066df6491dccd744ee87ff01a90           3473.0             15.0
# 4  003f8a76cb823eb7c58b6d052c57a8933f9275fd          47468.0            251.0
#
#    page_views_nav3  page_views_nav4  page_views_nav5  page_views_nav6
# 0              NaN              NaN             30.0             48.0
# 1              NaN             25.0             93.0             25.0
# 2              NaN              NaN              5.0              NaN
# 3              NaN             25.0              NaN              NaN
# 4              NaN             55.0              NaN             10.0

# %% [markdown]
# ##### b) Summarize sales quantity for products of different transaction types (total of 2 types)

# %%
type_sales = sales.groupby(['sku_hash','type'])['sales_quantity'].sum().reset_index()
type_sales = type_sales.pivot(index = 'sku_hash',columns = 'type',values = 'sales_quantity').reset_index()
type_sales.columns = ['sku_hash', 'sales_quantity_type1', 'sales_quantity_type2']

# %%
type_sales.head()
# Out:
#                                    sku_hash  sales_quantity_type1  \
# 0  000cb631113e2f54ca5512139a6592e9584957aa                 104.0
# 1  0020d561eab8b88ab55dfde84a2f12b865e5e0b4                 325.0
# 2  0026e7a0fcfe5999a44b70b1acaff00fc1ad3ac2                  85.0
# 3  00287bbb94c12066df6491dccd744ee87ff01a90                  35.0
# 4  003f8a76cb823eb7c58b6d052c57a8933f9275fd                 253.0
#
#    sales_quantity_type2
# 0                  10.0
# 1                  40.0
# 2                  25.0
# 3                  10.0
# 4                 145.0

# %% [markdown]
# ##### c) Summarize sales quantity for products in different zones (total of 5 zones)

# %%
zone_sales = sales.groupby(['sku_hash','zone_number'])['sales_quantity'].sum().reset_index()

zone_sales = zone_sales.pivot(index = 'sku_hash',columns = 'zone_number',values = 'sales_quantity').reset_index()
zone_sales.columns = ['sku_hash', 
                      'sales_quantity_zone1', 'sales_quantity_zone2', 'sales_quantity_zone3', 
                      'sales_quantity_zone4', 'sales_quantity_zone5']

# %%
zone_sales.head()
# Out:
#                                    sku_hash  sales_quantity_zone1  \
# 0  000cb631113e2f54ca5512139a6592e9584957aa                  20.0
# 1  0020d561eab8b88ab55dfde84a2f12b865e5e0b4                   NaN
# 2  0026e7a0fcfe5999a44b70b1acaff00fc1ad3ac2                  55.0
# 3  00287bbb94c12066df6491dccd744ee87ff01a90                  10.0
# 4  003f8a76cb823eb7c58b6d052c57a8933f9275fd                  45.0
#
#    sales_quantity_zone2  sales_quantity_zone3  sales_quantity_zone4  \
# 0                   5.0                  15.0                  50.0
# 1                   NaN                  82.0                  20.0
# 2                  35.0                  10.0                   NaN
# 3                   NaN                   5.0                  30.0
# 4                 148.0                  50.0                 140.0
#
#    sales_quantity_zone5
# 0                  24.0
# 1                 263.0
# 2                  10.0
# 3                   NaN
# 4                  15.0

# %% [markdown]
# ##### d) Summarize sales quantity for products of different online performances (page views, social network posts, mentions, and impressions, brand positive, negative, and net sentiments)

# %%
navigation_stats = navigation.groupby(['sku_hash'])['page_views'].sum().reset_index(name='page_views')
sales_stats = sales.groupby(['sku_hash'])[['sales_quantity','TotalBuzzPost', 'TotalBuzz','NetSentiment', 'PositiveSentiment', 'NegativeSentiment', 'Impressions']].sum().reset_index()

# %%
navigation_stats.head()
# Out:
#                                    sku_hash  page_views
# 0  000cb631113e2f54ca5512139a6592e9584957aa        1866
# 1  0020d561eab8b88ab55dfde84a2f12b865e5e0b4       16729
# 2  0026e7a0fcfe5999a44b70b1acaff00fc1ad3ac2         157
# 3  00287bbb94c12066df6491dccd744ee87ff01a90        3513
# 4  003f8a76cb823eb7c58b6d052c57a8933f9275fd       47784

# %%
sales_stats.head()
# Out:
#                                    sku_hash  sales_quantity  TotalBuzzPost  \
# 0  000cb631113e2f54ca5512139a6592e9584957aa             114      1308458.0
# 1  0020d561eab8b88ab55dfde84a2f12b865e5e0b4             365       497215.0
# 2  0026e7a0fcfe5999a44b70b1acaff00fc1ad3ac2             110      1206926.0
# 3  00287bbb94c12066df6491dccd744ee87ff01a90              45       475098.0
# 4  003f8a76cb823eb7c58b6d052c57a8933f9275fd             398      3282466.0
#
#    TotalBuzz  NetSentiment  PositiveSentiment  NegativeSentiment   Impressions
# 0  1791611.0   1471.884478           469288.0            67668.0  8.729030e+09
# 1   803633.0    851.430118           228523.0            38871.0  4.159187e+09
# 2  1718843.0   1380.767295           524646.0           100366.0  1.121427e+10
# 3   680543.0    581.175056           211602.0            33527.0  3.253251e+09
# 4  4795323.0   3742.253384          1401916.0           307473.0  2.389471e+10

# %% [markdown]
# #### Process data to prepare for modeling
# #### 1) Slice the training data into 5 parts to prepare for cross validation

# %%
train['idx'] = pd.Categorical(train.sku_hash).codes
train['idx'] = train['idx'] % 5
train.head()
# Out:
#                                            ID  month  \
# 0  3d8a4ae769b526187c36901f204691a663333fa4_1      1
# 1  c05a54f7067be054ec4b27d0d6081353ef7d9df6_1      1
# 2  7cb4d3626bd48a9b523d8693266219c34aeccde8_1      1
# 3  8e5967f90ff9fb93aa2840fceecc537b2e8e6ff3_1      1
# 4  6913a128945e0efeafc52101dcdeaa610eaa4430_1      1
#
#                                    sku_hash   product_type product_gender  \
# 0  3d8a4ae769b526187c36901f204691a663333fa4  Leather Goods          Women
# 1  c05a54f7067be054ec4b27d0d6081353ef7d9df6    Accessories          Women
# 2  7cb4d3626bd48a9b523d8693266219c34aeccde8  Leather Goods          Women
# 3  8e5967f90ff9fb93aa2840fceecc537b2e8e6ff3  Leather Goods          Women
# 4  6913a128945e0efeafc52101dcdeaa610eaa4430    Accessories            Men
#
#       macro_function             function     sub_function  \
# 0     LG ACCESSORIES  SMALL LEATHER GOODS  COMPACT WALLETS
# 1  FANCY ACCESSORIES           BAG CHARMS       BAG CHARMS
# 2          CITY BAGS           DAILY BAGS    SHOULDER BAGS
# 3          CITY BAGS           DAILY BAGS    SHOULDER BAGS
# 4    FASHION JEWELRY            NECKLACES        NECKLACES
#
#                        model     aesthetic_sub_line  ...  target mean_target  \
# 0               PF.VICTORINE            DAMIER AZUR  ...  1366.0  471.000000
# 1     BAG CHARM PETITE MALLE  SANS LIGNE ESTHETIQUE  ...   526.0         NaN
# 2                   GIROLATA                 MAHINA  ...   503.0  297.333333
# 3                   GIROLATA                 MAHINA  ...   276.0  373.000000
# 4  COLL.CHARMS FOR GENTLEMEN  SANS LIGNE ESTHETIQUE  ...   206.0         NaN
#
#    macro_function_count function_count  sub_function_count  model_count  \
# 0                  2292           2094                 447           90
# 1                   546            126                 102            3
# 2                  3039           2784                 699           15
# 3                  3039           2784                 699           15
# 4                   843            171                 162            3
#
#    aesthetic_sub_line_count  macro_material_count  color_count  idx
# 0                       126                  3213        120.0    1
# 1                      3477                  3213          NaN    1
# 2                        90                  4089         39.0    4
# 3                        90                  4089         60.0    2
# 4                      3477                  1023          NaN    0
#
# [5 rows x 24 columns]

# %% [markdown]
# #### 2) Merge all the summarized features into training data

# %%
X = train.copy()
X = X.merge(navigation_stats, on = 'sku_hash', how = 'left')
X = X.merge(sales_stats, on = 'sku_hash', how = 'left')
X = X.merge(traffic_source_views, on = 'sku_hash', how = 'left')
X = X.merge(type_sales, on = 'sku_hash', how = 'left')
X = X.merge(zone_sales, on = 'sku_hash', how = 'left')
X.head()
# Out:
#                                            ID  month  \
# 0  3d8a4ae769b526187c36901f204691a663333fa4_1      1
# 1  c05a54f7067be054ec4b27d0d6081353ef7d9df6_1      1
# 2  7cb4d3626bd48a9b523d8693266219c34aeccde8_1      1
# 3  8e5967f90ff9fb93aa2840fceecc537b2e8e6ff3_1      1
# 4  6913a128945e0efeafc52101dcdeaa610eaa4430_1      1
#
#                                    sku_hash   product_type product_gender  \
# 0  3d8a4ae769b526187c36901f204691a663333fa4  Leather Goods          Women
# 1  c05a54f7067be054ec4b27d0d6081353ef7d9df6    Accessories          Women
# 2  7cb4d3626bd48a9b523d8693266219c34aeccde8  Leather Goods          Women
# 3  8e5967f90ff9fb93aa2840fceecc537b2e8e6ff3  Leather Goods          Women
# 4  6913a128945e0efeafc52101dcdeaa610eaa4430    Accessories            Men
#
#       macro_function             function     sub_function  \
# 0     LG ACCESSORIES  SMALL LEATHER GOODS  COMPACT WALLETS
# 1  FANCY ACCESSORIES           BAG CHARMS       BAG CHARMS
# 2          CITY BAGS           DAILY BAGS    SHOULDER BAGS
# 3          CITY BAGS           DAILY BAGS    SHOULDER BAGS
# 4    FASHION JEWELRY            NECKLACES        NECKLACES
#
#                        model     aesthetic_sub_line  ... page_views_nav4  \
# 0               PF.VICTORINE            DAMIER AZUR  ...            20.0
# 1     BAG CHARM PETITE MALLE  SANS LIGNE ESTHETIQUE  ...             NaN
# 2                   GIROLATA                 MAHINA  ...            10.0
# 3                   GIROLATA                 MAHINA  ...             5.0
# 4  COLL.CHARMS FOR GENTLEMEN  SANS LIGNE ESTHETIQUE  ...             NaN
#
#   page_views_nav5  page_views_nav6 sales_quantity_type1  sales_quantity_type2  \
# 0            25.0             29.0                946.0                 554.0
# 1            39.0              NaN                338.0                  60.0
# 2            10.0              5.0                429.0                 145.0
# 3            10.0              5.0                228.0                  55.0
# 4             5.0              NaN                110.0                  25.0
#
#    sales_quantity_zone1  sales_quantity_zone2  sales_quantity_zone3  \
# 0                 506.0                 238.0                  75.0
# 1                  84.0                  55.0                  25.0
# 2                 190.0                  55.0                  35.0
# 3                 108.0                  55.0                  20.0
# 4                  35.0                   5.0                  20.0
#
#    sales_quantity_zone4  sales_quantity_zone5
# 0                 544.0                 137.0
# 1                 155.0                  79.0
# 2                 195.0                  99.0
# 3                  20.0                  80.0
# 4                  30.0                  45.0
#
# [5 rows x 45 columns]

# %%
X = train.copy()
X = X.merge(navigation_stats, on = 'sku_hash', how = 'left')
X = X.merge(sales_stats, on = 'sku_hash', how = 'left')
X = X.merge(traffic_source_views, on = 'sku_hash', how = 'left')
X = X.merge(type_sales, on = 'sku_hash', how = 'left')
X = X.merge(zone_sales, on = 'sku_hash', how = 'left')

# %% [markdown]
# #### 3) Preprocess features by changing labels (e.g., “women” as “-1”) and log transformation of y (target sales quantity)

# %%
X.loc[X.product_type=='Accessories','product_type'] = '0'
X.loc[X.product_type=='Leather Goods','product_type'] = '1'
X.product_type = X.product_type.astype(int)

X.loc[X.product_gender=='Women','product_gender'] = '-1'
X.loc[X.product_gender=='Unisex','product_gender'] = '0'
X.loc[X.product_gender=='Men','product_gender'] = '1'
X.product_gender = X.product_gender.astype(int)

# Change labels 
# Log transformation
X['y'] = np.log(X['target']+1)

# %%
X.head()
# Out:
#                                            ID  month  \
# 0  3d8a4ae769b526187c36901f204691a663333fa4_1      1
# 1  c05a54f7067be054ec4b27d0d6081353ef7d9df6_1      1
# 2  7cb4d3626bd48a9b523d8693266219c34aeccde8_1      1
# 3  8e5967f90ff9fb93aa2840fceecc537b2e8e6ff3_1      1
# 4  6913a128945e0efeafc52101dcdeaa610eaa4430_1      1
#
#                                    sku_hash  product_type  product_gender  \
# 0  3d8a4ae769b526187c36901f204691a663333fa4             1              -1
# 1  c05a54f7067be054ec4b27d0d6081353ef7d9df6             0              -1
# 2  7cb4d3626bd48a9b523d8693266219c34aeccde8             1              -1
# 3  8e5967f90ff9fb93aa2840fceecc537b2e8e6ff3             1              -1
# 4  6913a128945e0efeafc52101dcdeaa610eaa4430             0               1
#
#       macro_function             function     sub_function  \
# 0     LG ACCESSORIES  SMALL LEATHER GOODS  COMPACT WALLETS
# 1  FANCY ACCESSORIES           BAG CHARMS       BAG CHARMS
# 2          CITY BAGS           DAILY BAGS    SHOULDER BAGS
# 3          CITY BAGS           DAILY BAGS    SHOULDER BAGS
# 4    FASHION JEWELRY            NECKLACES        NECKLACES
#
#                        model     aesthetic_sub_line  ... page_views_nav5  \
# 0               PF.VICTORINE            DAMIER AZUR  ...            25.0
# 1     BAG CHARM PETITE MALLE  SANS LIGNE ESTHETIQUE  ...            39.0
# 2                   GIROLATA                 MAHINA  ...            10.0
# 3                   GIROLATA                 MAHINA  ...            10.0
# 4  COLL.CHARMS FOR GENTLEMEN  SANS LIGNE ESTHETIQUE  ...             5.0
#
#   page_views_nav6  sales_quantity_type1 sales_quantity_type2  \
# 0            29.0                 946.0                554.0
# 1             NaN                 338.0                 60.0
# 2             5.0                 429.0                145.0
# 3             5.0                 228.0                 55.0
# 4             NaN                 110.0                 25.0
#
#    sales_quantity_zone1  sales_quantity_zone2  sales_quantity_zone3  \
# 0                 506.0                 238.0                  75.0
# 1                  84.0                  55.0                  25.0
# 2                 190.0                  55.0                  35.0
# 3                 108.0                  55.0                  20.0
# 4                  35.0                   5.0                  20.0
#
#    sales_quantity_zone4  sales_quantity_zone5         y
# 0                 544.0                 137.0  7.220374
# 1                 155.0                  79.0  6.267201
# 2                 195.0                  99.0  6.222576
# 3                  20.0                  80.0  5.624018
# 4                  30.0                  45.0  5.332719
#
# [5 rows x 46 columns]

# %% [markdown]
# #### 4) Repeat 2) and 3) for test data

# %%
Z = test.copy()
Z = Z.merge(navigation_stats, on = 'sku_hash', how = 'left')
Z = Z.merge(sales_stats, on = 'sku_hash', how = 'left')
Z = Z.merge(traffic_source_views, on = 'sku_hash', how = 'left')
Z = Z.merge(type_sales, on = 'sku_hash', how = 'left')
Z = Z.merge(zone_sales, on = 'sku_hash', how = 'left')

Z.loc[Z.product_type=='Accessories','product_type'] = '0'
Z.loc[Z.product_type=='Leather Goods','product_type'] = '1'
Z.product_type = Z.product_type.astype(int)

Z.loc[Z.product_gender=='Women','product_gender'] = '-1'
Z.loc[Z.product_gender=='Unisex','product_gender'] = '0'
Z.loc[Z.product_gender=='Men','product_gender'] = '1'
Z.product_gender = Z.product_gender.astype(int)

# %% [markdown]
# #### 5) Create a set for all features

# %%
features = ['product_type', 'product_gender', 
            'page_views', 'sales_quantity',
            'TotalBuzzPost', 'TotalBuzz', 'NetSentiment', 'PositiveSentiment', 'NegativeSentiment', 'Impressions',
            'fr_FR_price',
            'macro_function_count', 'function_count', 'sub_function_count', 'model_count', 'aesthetic_sub_line_count', 'macro_material_count', 'color_count',
            'page_views_nav1', 'page_views_nav2', 'page_views_nav3', 'page_views_nav4', 'page_views_nav5', 'page_views_nav6',
            'sales_quantity_type1', 'sales_quantity_type2',
            'sales_quantity_zone1','sales_quantity_zone2','sales_quantity_zone3', 'sales_quantity_zone4','sales_quantity_zone5',
            'mean_target',]

# %% [markdown]
# #### 6) Define a custom train-test split function for cross validation with XGBoost (select from a specific month)

# %%
# Select from a specific month

def train_test_split(tr, te, mo, feats, num_folds):
    
    Xtrain = []
    ytrain = []
    dtrain = []
    Xval = []
    yval = []
    dval =[]
    
    for i in range(num_folds):
        Xtrain.append(tr.loc[(tr.month==mo)&(tr.idx != i),feats].values)
        ytrain.append(tr.loc[(tr.month==mo)&(tr.idx != i),'y'].values)
        dtrain.append(xgb.DMatrix(Xtrain[i],ytrain[i]))
        
        Xval.append(tr.loc[(tr.month==mo)&(tr.idx == i),feats].values)
        yval.append(tr.loc[(tr.month==mo)&(tr.idx == i),'y'].values)
        dval.append(xgb.DMatrix(Xval[i],yval[i]))
        
    Xtest = te.loc[(te.month ==mo),feats].values
    dtest = xgb.DMatrix(Xtest)
    
    return dtrain, dval, dtest

# %% [markdown]
# ### XGBoost Parameters
# #### Set parameters
# #### 1) Objective is to do regression
# #### 2) Evaluation metric is RMSE
# #### 3) Booster is gbtree
# #### 4) Set parameters for
# ##### eta (0.025, slower learning and potentially better convergence)
# ##### subsample (0.7, 70% of the data will be used in each round)
# ##### colsample_bytree (70% of the features will be used in each tree)
# ##### num_parallel_tree (3 parallel trees to grow during training)
# ##### min_child_weight (25 as minimum sum of instance weight needed in a child to prevent overfitting)
# ##### gamma (5 as minimum loss reduction required to make a further partition on a leaf node to control tree complexity)
# ##### max_depth (3 as maximum depth of each decision tree in the ensemble to control tree complexity and overfitting)

# %%
param = {}
param['objective'] = 'reg:squarederror'
param['eval_metric'] =  'rmse'
param['booster'] = 'gbtree'
param['eta'] = 0.025
param['subsample'] = 0.7
param['colsample_bytree'] = 0.7
param['num_parallel_tree'] = 3
param['min_child_weight'] = 25
param['gamma'] = 5
param['max_depth'] =  3

# %% [markdown]
# ### Model Results:
# #### Then I used configured parameters to generate model results for Month 1, Month 2, and Month 3. I set the maximum number of boosting rounds or iterations as 50000, and the early_stopping_rounds as 20. I created oof_m1 and oof_test_m1 to store predictions for validation and test data sets respectively for Month 1.
# #### Eventually, I created test_m1 to store the final prediction for the test dataset by taking the mean of predictions from each of the five models.
# #### I also repeated these steps for Month 2 and 3.

# %%
dtrain, dval, dtest = train_test_split(tr = X, te = Z, mo = 1, feats = features, num_folds = 5)

model_m1 = []
for i in range(5):
    model_m1.append(
        xgb.train(param,
                 dtrain[i],
                 50000,
                 [(dtrain[i],'train'),(dval[i],'eval')],
                  early_stopping_rounds = 20,
                  verbose_eval = False
                 )
    )
    
oof_m1 = []
oof_test_m1 = []
for i in range(5):
    oof_m1.append(model_m1[i].predict(dval[i]))
    oof_test_m1.append(model_m1[i].predict(dtest))
    
test_m1 = np.mean(oof_test_m1,axis=0)
# Out:
# /Users/lantianli/opt/anaconda3/lib/python3.9/site-packages/xgboost/core.py:617: FutureWarning: Pass `evals` as keyword args.
#   warnings.warn(msg, FutureWarning)

# %%
m1={}
for i in range(5):
    m1 = {**m1,**dict(zip(X.loc[(X.month==1)&(X.idx==i),'sku_hash'],oof_m1[i]))}

# %%
m1
# Out:
# {'6913a128945e0efeafc52101dcdeaa610eaa4430': 4.810672,
#  '170eb219ebb142d32d3068021552530f9895d0ef': 5.735153,
#  '9911283f6be7a225917a4c544a6ea95f0e75af4c': 6.1472316,
#  'c55e065bcb1d4c72bc2a9af949bb310661bb344b': 5.959349,
#  'b1234d5dd478535cb4e9966066d84ed24c0463b2': 4.9685574,
#  'b7d77ce215c5f55f421bbed636611831ba49bc60': 6.21495,
#  '83342f4739356582ac1ae63954b778978a317634': 4.5605187,
#  '59843c8d8c51d84ce1dae53dc5951ffd682b4362': 5.780509,
#  '81a12b07f6b90da9efe190b1581d553d3e3218aa': 6.2682133,
#  'c7154c00150a80c84cac7a700363a0a6fbc295f9': 5.7505574,
#  '34e7009d03294379ae04a7c2e86772b713f10fdc': 5.4926744,
#  '6c778b877ecd529be12266d4ecc2d05b81176418': 5.5789886,
#  '23bf25ee278cd834c05d6a73f60517ca35507513': 5.8263626,
#  '713f047a7e3798c764291733d3854100fe506da8': 5.388392,
#  'df71b29c540ed084f55764f5ca061a32847ad4f2': 6.71433,
#  '384dc35dbbaaeb7cf8fa765484cad3f37e0561e8': 6.879678,
#  '1b21e6b4e46346f3a635baf41beb98fa94595b79': 4.706259,
#  '554dd93733ddaa21a2a34982fff7188147180a44': 4.5592737,
#  'ef8c6f4514d689725452a3573eedaa3e283befe6': 4.481734,
#  '528e8b36cc50f53af20f66398a2d676fff38920a': 4.6277394,
#  'd7bdf2c8dcbf3cdd2e0d0ef5e0eaaa5aeaed2546': 5.18064,
#  '4975d1335cf315dc3cec1366d0d693825a45580b': 6.100972,
#  '7396a17cc295883d6270b234d7cc88e7c30b9737': 5.4927545,
#  '479a8d9273ffd5a58c0ffde339174f293acc5fdb': 4.551053,
#  'e6bf74e3999bc2bd5c02430e279f44ad1a4f2cba': 4.5381913,
#  '785a19583d57e94153d636d0738ed9dfdde4ee0d': 5.271496,
#  '89ef7fe95f4500a00eaea7dff11206b3f0f9d50b': 5.0919986,
#  'db0f421bf3cb82fe6e9bcd8a3154169869ff9cae': 4.6254754,
#  '251f2f0cdb88f6ccbcd0f4f0165971ce03d06539': 5.3361115,
#  '4a5c0eaabf33884b99eef47f97d88f95843e85ef': 5.837588,
#  '9ee3114010b034b7c88841c737ded0448c9d4067': 4.74872,
#  'd962d4548f97088fb46a2e11103f0296ac8f402a': 6.3027368,
#  'cbea688233065ad859a2d970e2d5bfea811c003c': 5.503802,
#  'f21aa8f21cec9b6b430ecc5800333d1e5ae7f54d': 6.8242965,
#  'ec44598a9da80723ae5fa114de1e48cccdf52952': 5.878433,
#  '073862ee041134789e6bcdc81163b6d6b23f7c4f': 4.9588866,
#  '8a4d735fa437dd90d080b6ea637c6aacd60030c2': 5.0445223,
#  'b46ad55335d1778f4599f91ee7df0c1a997fd6b6': 5.2335377,
#  '3f2ae9c7240e60051f975d2e521f26e1dc79fdbe': 5.0043006,
#  '799bd8691fe0be0137173eadd5e79d033a389bd8': 5.937049,
#  '1b8e6b205404ad64814c37868424c3bbe184fe6d': 4.444099,
#  '48f24dd8bf47f1441a8bfffe7a0a0d4ad55941f2': 5.168964,
#  '548569c10b89563ede707e865d2a458442391bb3': 5.429464,
#  '5d5b18c971507608b04d55d0e4e414b8b6c3ae04': 4.9511485,
#  '1d2db8d2e3f2020a5bc51e1785b1d2131c46dcc7': 6.3893604,
#  '998ea05c2e4ed904ad7a9d8a74253b1a5594c43a': 4.802423,
#  '85bd83f86c8a1fabbe111fa98995de6af45a636a': 4.53436,
#  'af7a5b9b9b61ae7345c1f7e8edb18efd22d264f7': 4.5300736,
#  '3e0871dd1a23c19b0153c62f97758868e8bfecf4': 5.0460997,
#  '2edd249a69647373520064b40ff5c7ccb0db9ea8': 6.673201,
#  '196e00163ddd765dbad96797f06812661267804a': 5.4835887,
#  '2e54d896ee304a5d0e771b5f6301220b31545c6f': 6.535155,
#  '4ea78d292bdf3fb416f1843b1f7cafa1bac697b8': 4.44053,
#  'fa3482cbab521c271e623a774c2f7b4a4f6dc0be': 5.138418,
#  '393c9bd01043039481d07f3675fa8ca67db19e0b': 4.8564477,
#  '3a85107b996ba4b14ae747804dbd234caae4ac51': 4.4968643,
#  '014525ee54d68319ef0f19b0bbeb97cd13770225': 4.820843,
#  'dd588124dffcd7aef814942a3e9877e54815bc9e': 5.0775967,
#  '27f8392afbdb3da73fab9eb6be78c9919a38471d': 4.5648775,
#  '3312d8e7153c7836210d48811e3b75f776d2203c': 5.10654,
#  'eb6072e0da7585fd25f0dd54adac6ef5fb8d5f1f': 6.2690372,
#  '0af642f427264bf458ccac964881e27ba5c7f33e': 5.295654,
#  '5e3a10304078861bd341a0c57b1db90400cb82b4': 5.093722,
#  '35dcdb42f8b03fa44c74528ee8a56f77e1868e2c': 6.4789157,
#  'd2b292ee1a58a01b77ee99532b50ee7b635dcd37': 6.373942,
#  'd21464c60827456bb2b625b58f831b011dd1d93b': 4.4385815,
#  '8e37856440eaa7f8c19f17f6489ae6528651b3ee': 5.528696,
#  'c2eec54c0656af0c0812f881fa4ce9e75527bc32': 5.017584,
#  'e151c7f0c49b3f7dca67d97ef2f446ef6cbde1d8': 4.444979,
#  '9f0a5574af686c42adc000ad95c437eb1d6f2ea8': 7.099813,
#  '4593fcca20fc6205ae0aa1d732b235d7318da8e9': 6.3164334,
#  'b5fc8aa508e05e0a95eee63a5a32f5927af8d37c': 5.085923,
#  'aceabad24ad125e604d4c5c36997f679b821dd40': 5.3217316,
#  '86b325e941675a8fdc2754193491b6617f7b43d0': 6.0111175,
#  'baf2d4020d4efba0cb2bc4c4c63f2ac0eb9e8a54': 5.1159844,
#  '05a533f8a94c4ba4c9aad8d086cf2eb2e6c83e17': 5.195221,
#  'a4eaf47facc259f02374e16d63613b36475ddeb5': 4.790903,
#  '6a727bd8e7c69a7c3a2a73fbe22b5c42ca2be8fb': 4.6289053,
#  'c651f56c2c8d4b66df0bc099fbf76f1e1c5d862b': 5.685695,
#  '69ff437caf42aa7d9580f42a93b5cf1c4b7dc872': 4.44674,
#  '7073b5164dc9f52846e4674229dc7c17916aedda': 6.6860547,
#  'a1ee779fa34d71502d806f99f70b6550b1ebc092': 6.740294,
#  '448f5cfd5b3d34765819739ac82d39dd57a8e686': 4.5147405,
#  '7b9900fd605da7fba5604b4896626d3b5e85420d': 4.6061096,
#  'd56b8e1ac9f8e2e0572b32c188a428498614f0b9': 5.0280414,
#  '1248df7f4190597a8d8949e40a16e65b03d220f6': 6.337882,
#  '38e0d41106a4214e1e353de48d84423527e482c1': 5.6503158,
#  '530aa695c66f2a1156367a78cfa1415f3544ed9f': 5.665581,
#  'fbdce350289c573218c0a26130ee60fc763ccc60': 5.6494155,
#  '1f5a8d29170ea66c23042eb69f02637967da45ef': 4.44674,
#  '4354e66d1c5567f76f7cd3b83a94b39c05de8975': 5.0541387,
#  'f32a403be92e1c2c3561351d534079f00a1ea93d': 5.062144,
#  'adf60db5c41d7a58930c360fc2858af0bf3d3d82': 4.7481556,
#  '6afe2b0f4d4541dfe9b66de9e824ee8e667c9598': 4.447709,
#  '1ec4a52fb83246c09f02aed9e34ed49f800274b8': 4.445384,
#  '5bb2dda83e3e9537cb7f92cd245123834ead8db6': 4.4625783,
#  '828b0a63dbcbe52dd93d983e8a7b6e292e1a781d': 6.2511,
#  '2868ed7f436a4eb1cfe9a01abcd84d1ddf025013': 7.178705,
#  '8bea64ddf564ae58c51341c40511a868c9cbdde9': 4.7151737,
#  'b87ceb696b284183f8179158c65ba1ad6aca4998': 6.247838,
#  '6f808b4e676bcd38d02290402b6cdff06aeac620': 5.9375424,
#  'f7d29242d97ccad30d7bd5dc18d39d31e7512522': 5.870741,
#  'fff06e7dd5889cbac572ca564c2a91c05f009743': 5.0311694,
#  '0b81c181f3b00c5d0cf7f2c14dcc46031dd4d5b1': 6.1628985,
#  'a2e637465f2db0c780caee24de6ef46f47e12d6a': 4.4641976,
#  '7c92f3d736af282e5aa23068c7554e5f244c413c': 5.4499187,
#  'a3628e485539b9a9c47124cf76fba9cb224bce00': 4.5955977,
#  '10ff66d03b63192f2ecedecf30a566396ecba374': 4.676647,
#  'b2dacb34904212531dd43878284bbca052689020': 4.659588,
#  'ccd0efb7677a79bcf0f424f2c740bc55b659084f': 5.8206882,
#  '5ee9cee2362c6add79fe80436821a9435b63d72c': 4.6969824,
#  '625dc1419ab858d0adc99d746dbabeb3770e8fa1': 5.409443,
#  '9ded7ce0f29a14bae93bb8d40ba1daa8e9c781c8': 5.303362,
#  '9cff3c17191a9cd8332050c8f99f2fc842fe9bca': 4.855158,
#  'be419567c5d5a0730e40ee878abc241383948040': 5.691351,
#  '54f81fe6feb88b5a1f7e7a602abf5951668e8d9a': 4.5465956,
#  '877fb63a0fe5802ebdf3785466ca8e1d45a71573': 5.1502366,
#  'ea8bbd0c5dacc6a9f5c1d948b26165b862f1520e': 6.4694114,
#  '2356e646a6226cb36c0ca5fcecd06499a7c11c0b': 4.675693,
#  'ba92ee85712bb0adc5147cac61c8f8a498784489': 6.207338,
#  '8964a916d22f65028e5688c2b10d025c0bb8467d': 4.4537587,
#  '65019abe050575c19d306ee8e7aebf52f380469e': 4.919445,
#  'f2b9f62dd285cf160e35182f9e37fbc238cdc233': 6.4035935,
#  '22c9064178ba7635b917e87db06e95e8b762d12e': 6.2917113,
#  '14e818ee482e32f5758d3e52c6a3b193f7c1718a': 5.033812,
#  '01c26e5c058780ca2c60177eca1f26e659579fd4': 4.6991186,
#  '41121e50f025f984680adf79a08252d303de750b': 4.4208474,
#  '000cb631113e2f54ca5512139a6592e9584957aa': 4.7557907,
#  'd884da07771321faad63098a42755e502de299e6': 5.4373665,
#  '96c0d0085876373871aeaf72175b4cc4266d23b5': 4.8144693,
#  '921c31182f79c53f15e8e53cc340a52cc5af5f8f': 4.836586,
#  'd15d89ae2aea56e2b7499c0f389b266af0e81cc9': 4.724013,
#  'e725e0bd8ce69f81ee04465120bd6a118483546a': 6.3467555,
#  'aa0cb29e2bd90f77d87042a44c74c330576a852d': 5.150342,
#  '58248e1df34dd8b80a7834f699471fdd47c2872d': 4.427608,
#  '95623e413b41c2d1ea944da4fb2b9e85142e1a93': 5.845845,
#  '036a9b3bdf903045639ca079c57e36df416f0255': 4.96635,
#  '4d34b47ce6f17b9b066c1cad6602152994c5f0c8': 4.4498377,
#  'c8ac56cefc81424d681e3cb47fd059f6f8f04d67': 6.645411,
#  'bf2aceeeab9c18020e15599911c12ebad05a8abb': 5.0467496,
#  '0bde8a3e900339c9a1e60c45cb64edc4696ce3f6': 4.4543037,
#  '06bbef84905b2593c144b87456c70ebeee8a22ee': 5.2141013,
#  'fb864eb82336e816a1612df3ba3b27cf3622d55d': 6.0535603,
#  '32acdf0926971753d6cf0038b199a70ec1ce776e': 4.570491,
#  '189b22d409b603d0488366035b0bf3dc0a8847a1': 4.8561244,
#  '4f5aa9154b07d288317f37fcbcb08c1aef882843': 6.8274393,
#  '3024408b7bde861527f40c14ffdd35fe844d8737': 4.5120897,
#  'dc9233d833b7d9dcf7d92e9d7310b607e6c58d1f': 4.429886,
#  '72cd0cbd0d8854042409d03f44957e81ef560a36': 5.7677436,
#  '71c138efbfc1ead5ecdf23a420afe94944512a0b': 4.473371,
#  '3ca1925138f80c59d15967003a5c0b8b8f5efdf6': 6.447591,
#  'f4790d6c69f9afaa3bb25189622863ae72dc6a83': 4.6780334,
#  '69735835ed963759b7869f8693fde24e2548584c': 5.1895194,
#  '5cb8ee0219e8438ef6532178a99ab1613d9c0c1b': 5.837208,
#  'b040554737d8fa84ad73059d36907ab976e44278': 4.4155006,
#  'a5a36a31d5e1dafa2530fab7761d9a9b4567355c': 4.9155016,
#  'f65277cccfe03e89334c81aebe7db6d1ffedd23e': 5.1306076,
#  '4230938725c339c06d92cae0db715a7a778b6ae5': 5.274416,
#  '6ec141295937dfc4053bc255337ac5f0dbddd1c0': 5.6114454,
#  '0481ee930119798cefd331b3fa9e13d83be21256': 5.037258,
#  '7013164346bb1c8c0092fb3a029c55dadad8ade4': 4.7986345,
#  'cafab78f27c8f9c7d4baa0b71c8b883df6dfbfef': 5.060022,
#  '90a4a3cbe1f15d3c650ba1ebd6b2dd3926cfbfb4': 4.6496754,
#  'b91254e5195e2bf8cd2dd31f30fe76d90ccd69cb': 5.9002466,
#  'c9f0435e64dc7f5bf8f9a0e1ebdf43727aed24dd': 5.084104,
#  'cd9af80270ba2a1125b0985ad4cba57bc8adf4b1': 6.194285,
#  'f5be8acce8db7cd221041297186d2c63f8eba528': 4.6550694,
#  'b6466d1fe14462bf3902b11c234b46c92192d0a7': 5.787659,
#  'c18a0bca1418ddfecc343f59fd3078caf6ac2454': 4.4498377,
#  'a680aeb7f054aa8bec2e9cc6fdcb084f00ce2259': 6.4152308,
#  '7f75d07bf763aece572929637447be19e4d42608': 5.809559,
#  '66d413a467705f9eea033ad27d9863bde77c3d46': 4.6542325,
#  '941b9127ff30bb86911f9301a9e613f2305c517e': 4.818926,
#  '3792668d540ad3d7de9c111821a1fab3b21b4c1e': 5.4430485,
#  '8425158e5859759a3a010c2db4592ef84dcef8ad': 5.6099024,
#  'f54e5c3d5a169362f0dda8f615466ee333be6b6d': 6.639676,
#  '2f7a32d5c625ca3a0b206aada877e818ef9eb4bd': 4.9099045,
#  '3b7ed32be8d9c9ba1999cbf49a9eb7ced9442743': 4.4852543,
#  '7bfe373ba146cb7b0611edb5c12452047a999a7a': 6.5766635,
#  '0d77147100adb210e9f2ed4a7fb98b3dce8f87e7': 4.461105,
#  'e9e32902363d17e83a341f1a30ddca0ba5c0bdff': 4.8340526,
#  '6016706bbda526cff32d80676da1a32d3ae638c9': 4.6780334,
#  '5b46fb66c75cbb9e508a95700ab0ed5cc5ef9e58': 4.7481675,
#  'de2f1814d2f7f1b01a0fee5d8aa3b4b74213730b': 5.667204,
#  '9b2f34bcb3107c958835f074a6e5cfecbb96a11b': 6.1343203,
#  '7a2cc6521993f846ab437151ca7375470d504a5c': 6.1376524,
#  'a719fa3465cda27d4be676918313d0d180b36f91': 5.6946726,
#  'f69cdf5825f6a0b0ad640768ba4fe6d63c5eb221': 5.0888543,
#  'b5a27ddd78651223c817b8c7362961bf44ddafd9': 5.616113,
#  '02abae10ef5fc8e52fb98c9071196f07d2a0fa59': 7.090999,
#  '19b34e6ab4d8e679874742ef360e35ad00286351': 4.62819,
#  '9a384df44586bc3760d3f66d3b112d6de8d6aa1b': 6.5801597,
#  '60f388e2cc4f21889327c978aed355413bebdad8': 4.440591,
#  '2266d483f894613d2417c286a112d8d09ee63df8': 5.766667,
#  'b0aee3f87163917478296dc9159ec9547f81b2cc': 5.5942154,
#  '0ca9ae96a7b7bf50b29e184cb33221c2b44024c6': 6.4517984,
#  '9c50dc8e7da1a7a33b7cbd6287c6940921790407': 5.0788393,
#  'f757061614e1e72503c8e106b42ad4cef841fd7d': 6.219033,
#  'feb62e29f41621b06226be01fb6f7a68d5e1c779': 5.8419356,
#  'f910520b6f053fc56337ae5425613dbfec78926c': 4.417333,
#  'e7822f9963644957d6d86e40cfdfe082a027aee7': 4.4498377,
#  '3ffe1abb26e4ff1c7ae19a370c91222b4d1b2e52': 5.8581567,
#  '157feffd1108fe5a0815d62d97dc52162a0f00cb': 5.422325,
#  '7dec322dcb1d5f364486bec9824ad8e23e274008': 5.7349944,
#  '57d458b99aa3e8f84ba37ae75c1712f8c4e334e4': 4.6151314,
#  'efc77633556d51ce69d7f41e91181062ae56f652': 5.0202684,
#  'bbd709a8eecbddd2e2d2d5dede576782bc2aeb3c': 4.5784636,
#  '3d4fea2d2a7237c07adfe09b9463f41f2a5106bc': 5.079056,
#  'ed52346d0e50ef281e5494de6f525a6a85bb5379': 5.4246154,
#  '296f753a07d8d23ddf4e5e7b56e5afcbe9f6f2b8': 6.262053,
#  'da638c5026d818413b8b2160a8cec7f7128192fe': 4.475284,
#  '3660be2cb939f63012b4896a885d9e1b17cc3281': 7.2401166,
#  '2b5cad456d969e747941b406eef8b2a75868b53f': 6.999341,
#  '2cd8c77387dca332c9105c28c3d40ad7aeedcef9': 5.5124884,
#  'e0af9178464f336d4c495485dfa6b2614759be7b': 5.091173,
#  '7ee5c51762c905193dc9eaf921517f359266b58a': 6.241631,
#  'd5272498b30febec2078514a3e95cc26d96d6825': 4.631705,
#  'c0c25549170992fc7028a4c5caa7919e7a8d1146': 4.967594,
#  '204ebb1ab76e30aac01281dde6e5740f956262c9': 4.934981,
#  '6d7e068c5e52d6f27e25ea24a8f338478019a40b': 6.671446,
#  '470e0e62902b15b12ac286f8258c405cb210074e': 5.658239,
#  'dbb3d11b1ee2708a529268c7667a59e3bf30a1de': 6.142565,
#  'b9f6f59492639abe515063ff4583cf3140010840': 5.894901,
#  '320df29bc90ae133ce4f4e31f01030a97cfdf704': 4.5232306,
#  'ce3aeda49545db9b0c652b6e225f1e9b9fa5d6c2': 4.4498377,
#  '63933a61b1f69687871ff88d9a1792f83c5ae647': 4.4728527,
#  'd75537be48d2ba3a2e05e03651410f07fb079bc3': 5.1266146,
#  'e5f10f54e1a099b7f75be0641a5e5fc55cdc1d7c': 4.6692076,
#  '0c422736085259e4d5395b2f40a0a25760fa1484': 5.4165707,
#  '8b3146d7dc78a58a74161b9cc19c6f733ec0199d': 4.615459,
#  '4e165ae428489054fa22d43bbc137fa3ebbe16c6': 6.2315173,
#  'ff681b9089a461f701b0585990f6584c7ceb61b9': 4.9556603,
#  '4421d5113f92b0e020d4b051978eab21902c597c': 4.6453657,
#  '8ee475e64015edaacb2c45d384af6c66de4a6792': 4.468059,
#  '85e370b864352737281c36aa340c3d28cfbaafe1': 4.586832,
#  'cfb0f98931571cb200f6c296f801cde7f394b5cb': 5.870729,
#  '0a1795570facfcf9587d38e49da7d9b30aa82e25': 5.505886,
#  '50dd601f2b678889674b233ddd8442fcf1621ff7': 5.4817586,
#  '30e3e6273b8edc29ba935d787daf54892ce3999a': 4.518997,
#  '1e32c2cb642b9cf47b0aa0ce6367d8f403bf5e5c': 4.465793,
#  '0fd5a2d4cceba8a1fc93e02a67ef4608dc274079': 4.944426,
#  '564b6a44c4fb3a72043cfd761c6271f5a28d3750': 5.139519,
#  '24aa6deb1a1b334ab3eb3e442a1a19751237ff6c': 7.125894,
#  '2a577868cecefad36d5030c2663c8abc7d39b2e9': 5.475311,
#  '889306b34a21323d7dc8ca3714dcdfd955dab9e0': 5.8535137,
#  '13f501ee5b3b4705b3ac7d6f74415c7e62daade1': 6.1825304,
#  'd6ef2e73a2bec18c4a2c0a166373b589da2703f5': 4.998615,
#  '7cd6e6580264199825173d415898eb8bea85eb32': 4.4464355,
#  'bd8b649445bdc2b26a6f605a424d614229d3269b': 5.1181793,
#  'ee86520c6cd6a912074f96c73f3da0bc30a89468': 5.222487,
#  '97cb25ebeb71e3174caa50c13310ccb7897ac9ce': 5.2739086,
#  'e3c03220ec214303e151dc602dca35bb71b39ea3': 5.6897626,
#  'ac080a51e26da4eee2b53eba5db0dd7f5c7b626d': 4.536346,
#  '655d9a369930fc0dec3090f687503fa19b26272d': 4.5245886,
#  '575e800db5eb8d9f1e660126f42b1a91b1fe352f': 5.1377406,
#  'e95c191f0d43dcf8ff8bc961da0e6da0abcbbd0d': 4.748462,
#  'c0247d170d60dde62c0d4da1affe21078e3f7ce3': 5.3939652,
#  'fca4ea84e14b8b4bb07f5dfd2cace97ff5e86d61': 4.9453382,
#  '4c1e784d51a8d1702ebc3c1a2016101d2e6a9b10': 5.2533116,
#  'ecb3f60c58f3168cd6ba7d2418cb24019142794c': 5.1262226,
#  '0f3fa9386a7c76718f0082d63cc9a7e4f9746b37': 4.77419,
#  '10617d97441dffea08d02c5b698f108a78a67bfc': 6.0339046,
#  '2c0224f4ba36259620171c79022c5f44fef27b01': 4.8636208,
#  'a06a826b5645a687e9a7807e6dd7f81acb0699ee': 4.6702175,
#  '08e09927083a47011fa604e6120e6cf569332556': 5.092028,
#  '6451822546df24ce53e6499a25c7a6a15c80e2db': 4.4472165,
#  '9154fd6f8323481f290acdd276bfefbabb63604c': 5.3907857,
#  '5c5ee0ff4850fa659ae8f3f5414b1981ff03ad7b': 5.1476874,
#  '4dab590db3872c9caad5b0a6a01eff2aaa066cac': 6.5997024,
#  '1371ad27494875f11cc7db68694ecfc444f179ed': 5.3186526,
#  'e3023daa3800cbf7f1fac5730b30a3dfcb2e6af7': 6.660681,
#  'c9b5a65c3760f1082d26e1a855465d438c6009e9': 4.688325,
#  'abd434970db409fbd92aa726569235684366e2e1': 4.5781703,
#  'f97431200243f96429d96334a45afe408341b343': 6.7485433,
#  'b1e8186f3a59bc14c35238f90e1e628cafe9edd2': 5.4455395,
#  '7b20917a0b5d705b16f0465d93a94abedb8ca709': 6.2574835,
#  '67916e896689e2b9fa601268550e104de593c7db': 5.6077323,
#  '0e1a1abd06faa51017d55bbc33358513c427db93': 5.348868,
#  '27a8070143b55d2f931bbb4d156b1da599c93771': 4.556405,
#  'e23f92a51ee30e40a079cdce8a0bd08a34d09272': 4.6822214,
#  '6df055340957497aa536d307cce966556699d5df': 4.7636085,
#  'd4730c93b645a780b3dea44aa34bfc2d0e68b257': 4.4651837,
#  'c3d82d00d75ba146538ddb0de26a7d8cce7122bb': 4.685701,
#  '6e5cc20c40fc7e473dff5f3430baa4bde32a681d': 4.4993935,
#  '343cf4b9bcecb0d548891bd0f4dafdbac4028747': 6.627875,
#  'b72e43ab18a5bced6c79dd53fe134190714092f0': 4.79336,
#  '5191efcf9b1d38e4941e1018496e5ea3eec5ac78': 6.053792,
#  'c1fcca70802c95e65ad9a848f4209a5ce27b4580': 5.910181,
#  '14a00f676f289cb8976b05ff2063c4307c73ef2d': 4.6393886,
#  '3f966cec0c3748ed22edbcf39435a51d066dc69c': 4.4993014,
#  '25a0437c917da534eba0d778c6e7b1192389d333': 5.820046,
#  'cf5a4b60f37c6789bd8d59db0c093e26fa020f8e': 4.5375843,
#  'be8e5167970fdb4bfeda002f9e36d5a7ab1b5517': 4.6670055,
#  '081ad3b7eba67ef0369ed938c7f5f09c15b3c755': 6.2031984,
#  '40af31a060d2dae4f4a673e97b24fdc721a6e1d8': 4.4391785,
#  'cac101e5965c4971c8f4e49b742522f93ccf1a6e': 4.775358,
#  'a88594f7f74d5af24d131a8675fc776396e461b1': 4.92228,
#  '92ec24303e9a0109b2c3d19bee52230262de1a3b': 5.1165814,
#  '3713c45ba360b9bb63491813fdf0436d03a71a2d': 4.580445,
#  '42dee06fdcd5658d567ec7a96eac571fade68379': 5.070978,
#  '4b9d64fcb92f8bb8c6d9110a17396b2487d486b2': 4.7353463,
#  '6bedf4cda998347d7276b2c882755bc32c9413a2': 4.560272,
#  'e4923558b802e6b5c346175fa88f4b41264b1e87': 5.552595,
#  'f40e4dc5ba45236ce2a058d5f686f062ea5d4c06': 5.1812625,
#  '21b282a7d367f88efbce76e775ec50988d357672': 4.6869187,
#  'bc759c358e59a76b4c8f42cb9eef6d7b4fc5ee96': 4.682395,
#  '51ed1b8c54c9e316439f1584868baa185154185d': 4.877316,
#  '763ad6ffb6630b307f73afafd3173626f7267d42': 4.5275903,
#  '821c2f4140425c7cf4479b6aeb772014994c68e7': 5.655069,
#  '2105efd71874e19dce464991f670e6dbb959cd14': 5.003099,
#  '769d332aecd0a935331119bdbd447154ac7c1723': 6.0287566,
#  'ad47cf212f685b900aebc100e202df8e7cb632a7': 6.186211,
#  'c3701327b96aba635bfb4e3ce404f4bbf84d3e29': 5.668166,
#  '65ef30713a043200a535a26fd898510fa86c7bc6': 4.6864552,
#  '7a994f41572b1918b9f92771184a4b1b80586327': 6.4336824,
#  'd5f6b5b8a5bb2169158fd7f85fc76b51a864bcfc': 4.9059663,
#  'c7d3dd426accffd6545d9a860b1d0d59133df6d3': 4.780653,
#  'e8f3f78bd497f8187cb2dc24996e60bb7770e44a': 6.419628,
#  'aaade37184552196f09f057b88a86a4eba3d6e3e': 4.707215,
#  '952765c5adef6b721d50c5d7de0b4310f7836fdc': 5.328953,
#  'aeb82074a21c3ab2724c52a924ef75a17d074fda': 4.6920404,
#  '8ff9701a3bd8127a7e3935f7fd716efc886a31ee': 5.735389,
#  '8e6e18c84d49e41c5c21591bda22857f42b2aad0': 5.1644263,
#  '8d70eb8a07937abc1ddf0712a657496d5ed3cadc': 6.0375233,
#  '1c24d67a7204a7df8e104a37e165f54860909c0a': 4.5704656,
#  'e02bc9937cc061530f5bf771f78696884726bace': 5.6288376,
#  '75c60ea5d625c8fd725d7462019e59347e3139d6': 5.2468657,
#  '1c952c0e83af3500ba40a6a48300919659e27b8c': 6.3505454,
#  '3c6619128438d580c7df5486f8e9f3823db5a2cc': 6.5787992,
#  '17c070ce7001f568a6157bc8aa0095c940df65d1': 4.5900283,
#  '024c314d7eb29e953856f0d68c503e00eab3c27e': 4.5232673,
#  'a9671d29582327e1cfdc375bd982ec9648f1b90a': 4.4705777,
#  'a0301dd24a553e378535e51389da7277666b5b81': 4.480896,
#  '2657fd46efefd52bbbf88050c8ae3b0be759880b': 5.0304394,
#  '86cbdfaac0703d78f7dc8208a4d119279e2a6488': 4.735551,
#  'd3885743230127958682e61c9c9950c01b6d45e1': 4.602453,
#  'c593aae41331f4d4973ed0310b6fdc50834af371': 4.5300846,
#  '56ba7882f669a76efc62e05894c770ba2e91cdd6': 6.887036,
#  '1aba418ff76b5dc7ea514b3815eb7737220642fe': 5.4452877,
#  '5368ce315d3e645f174d0ddcc5d09aab1051ba00': 4.7185693,
#  'e558299b52d8a0d9836bee43e14714db1891479d': 5.9388776,
#  '5a07d7b3ca05c5289ca4159d1fe671b8580cc7de': 5.428449,
#  'f166bf7c01458755fde079e850f279f7ffc2790c': 5.08134,
#  'b4f55dd504ef4eb337a4e2446febdd92c72d997a': 4.4208474,
#  'f8a3027cb1e486bc0ab1bcfd02a0279212c96707': 5.20226,
#  '7479b6ffb5302bf20c09c7dac91b764a564d5cd0': 5.561016,
#  '319732285b97d32112d7623ddefc70b154da1070': 5.29443,
#  '6ce04c8dfa6e5926643a07201e345f663f44a020': 4.9788933,
#  '7ff4bfb05de6dcf60a654d584d743d4453ff80cf': 5.0283484,
#  'aefd87bf27f76c06051a4c21e9ea1867d80ae3ed': 5.4288883,
#  'd0a1373a766ccfab9a89a1b9f60cf3ae182ccc00': 4.45878,
#  '62f938bd02fedac5cd07edf37e6b5a07f613e42b': 6.205254,
#  'fde3e1872dbd16941f1ad0119663ec20de1f2449': 4.684243,
#  '502e3f47edaace7794acdd2ec6b50531d7ea5760': 7.049226,
#  '3d8a4ae769b526187c36901f204691a663333fa4': 6.7254677,
#  'c05a54f7067be054ec4b27d0d6081353ef7d9df6': 5.6559753,
#  '520a06a470791e2bd7719a5ad2d4d5bae011381a': 5.070441,
#  'cac33ca99e315554cac5ebefb99aa4a63db6be14': 6.363071,
#  '3c6cc007146fae68cbd4c23bd31ac9e3f80036ab': 6.413069,
#  '2f7bad2ffbdcff6e8a7e7673fd67562df2ef0634': 4.6269894,
#  '6db7a7f9ebd450cec9c5a7592bcc72d3dd8e86c6': 5.038624,
#  'e6da4a4e87dfa2623fcb6166af6158887e9c2a67': 4.5978017,
#  'c90f6c270670a59dde139bc2a2db05165f8fbe3d': 4.4566617,
#  '3bc124fe49d9734e28220ca294ea6eae84f152bb': 6.236408,
#  '3f2eb7b2d9e25d9f17a2537f4a8dc83b522e9e4a': 4.515355,
#  '6ec43e3f1f2490a48e2537116110676f83c0b057': 5.0623,
#  '14c263a04aef37291c0bd3294c465882feb994ce': 6.2564654,
#  '110634013e1161caf246be3891db161cbe0b1617': 5.427338,
#  '8bf84fe2fabbb81ceb9d261d70205f76fbe073f4': 6.230076,
#  '75cc6d98ffb772c27adbf07cb026569fbb29d034': 5.5522084,
#  'd57963a130c3c1393a8ece3973d4b9152356baec': 4.5170593,
#  '320f22e7890ca22f3cfca4490fcc1b4c735cb560': 4.4948835,
#  'b6872d033baecf398e76b7d8858a15578dd8a012': 4.536441,
#  '714fee9847e75259f6938e82ba6081a9acf40ec6': 5.147678,
#  '7ace898686b8443fbc230cd1577ee5b009443cca': 5.637503,
#  'fc196056262365a7fbb32fa267646a23e6159649': 4.526507,
#  '297d084dd6738df1abb36c5a8cd012e8e2c79f9a': 5.9318943,
#  '4f60616a319969ceef8fb13958f95c7e09cb11c2': 4.4305816,
#  '40071402d922d41de155d5a9c7209afebf58aeeb': 5.348062,
#  '4aeae1a26684fa2b0063ca1e8d305899462d48eb': 5.1734962,
#  '1c98909493426b147491dd0bba5c7791978486f4': 4.675157,
#  'fcf2d7a63838321b9642b140397d68e95fe7e08b': 4.45289,
#  '206ff2952d6ec069207e385259916067c5620fc6': 6.5201836,
#  '5051b75071727422379e358efa3b4f60c549c9a9': 6.072148,
#  'd52ac49421b02c1fe965d397043eb343259a7a1f': 4.518065,
#  '9deff0aa1d7ef9add1a09a3ab7260377165a00fd': 6.4374084,
#  '76a0c69cd3845cd1cdbd04451553206907d6bbfc': 5.9728026,
#  '5db2f6d02bd0ee5a9a54f90bc1f74089b78c51a0': 4.4921255,
#  '5a07ffe751fa000891800e464ab3aa996177f209': 6.5634937,
#  'de4114fc60f2aec56e23e0236c00e68c8cbf0555': 5.678932,
#  'f92d82cc9e2b620c9ea650080d957b12eb33cb10': 5.5546794,
#  '6b2f15df28d36fae382782384e0d93d68ade2a2e': 6.09651,
#  'c6619d766ae17fd5dbda91b22f45398d79222697': 5.304932,
#  'bdc822ccd9abe3b0f69eb6b9ee3c89b67e258bdd': 5.0104966,
#  '56561027f2314434ff3f88c113a0112fba22c83d': 5.0983434,
#  'eaa4aeb4e1de819844d61985f550823005fbbd3d': 6.0983734,
#  'd710945c4e8eeedb744d529cc2f64306c03c6aa7': 5.3255997,
#  'ad0046fb8c9133c58bbe17cfc4442f2d5344fa93': 5.1936617,
#  '4e196165af86a9658cdc7b2b79998f7cacefb112': 4.4864883,
#  'ae17bae830ed1a8000ea8263ca1af5661207bb59': 4.9071913,
#  'df7d7cb0b4857ad376448268b0f175ffebd87688': 6.1677833,
#  '8429397e6967bdc378d9d606165bca408917cdd7': 4.469633,
#  '8298f40b88552e6fc06ba57082a4b5eed8361dca': 5.3191366,
#  'f6a39161ee46547202d5abf497a6504a4482837a': 4.4719,
#  '626f0ad28913b75e95c3046ba3232d64f7847f71': 6.9230967,
#  '2e8f8cd63ce6a0e92dc7ba0d7b834e450d66570b': 4.4481835,
#  'd3b16060a216150f17c996cd3a83f7a4f584c99a': 5.530512,
#  'f196aab9ffea32c1d2cfe62070147c3a276849ab': 6.126708,
#  'c0c2a1cafc8c6181c76e4a8f2e9b22a91d0bcda5': 4.524365,
#  '8ee7668ef1c4836cda8ec675d90a172da6e1646a': 5.333021,
#  '97f4f7579dec69da02f9a94fc4478b96275dd30e': 6.592414,
#  '442c3cc060423e100d3b9d74c3ffe70aabb1a2df': 4.5288167,
#  '319f89670533117c5292d3d50ad40e9e1ed2349d': 4.6240234,
#  '1d30b4e1fc842fb7ae55c964d4295174a509d87d': 4.4936857,
#  '947a378759da2620f1c55aee2f37aa552b53a39f': 5.6574674,
#  '803697d00ec2d9dc9a7002b24cfa64bcf271bee5': 4.743378,
#  '5101326ea644ba630c9e5a02f1fa8e3d1431f13b': 6.255785,
#  '72cf183f90a6313fad7dda3e7dd9178e0bd83e0d': 5.077671,
#  '57d7dc87136e3a461145cc1c7ba29f64af8c50d9': 5.7255316,
#  '953556d1c4f5ea56f3e2f80839634e255df8ada6': 6.224926,
#  'f21d149ced5d084fe04a13f6dbed90543741253b': 5.8518343,
#  '0268e2469157153bddd6b36bf569c975a2621141': 5.501233,
#  '0b0c65e4ee377a57eaef978161f40e6e4bc73c07': 4.484711,
#  '30fead593872808d8c16d832cca2f303952bf93e': 5.1662827,
#  '898c652f370b13525f4adf05903530046ec0669d': 5.647713,
#  '96f3372a244ec948b0349255ef7e5e1e58a55e26': 4.7385974,
#  '83761a23c3bccf03f9f137a766a71d5e4226a5eb': 6.6580143,
#  '0020d561eab8b88ab55dfde84a2f12b865e5e0b4': 5.6696033,
#  '0be7aa9397abe0441f5a6da8a4096bfec7ab7be9': 6.149455,
#  'fa5ea8c5f31bfd5daa7dd222067433b07f161c56': 4.5206866,
#  '70169f2e4c8360e47c21e37eee4ffdd905b05b35': 6.076406,
#  '925a8071774d4229b0fa0ccf31546a33afed881f': 5.059403,
#  '937efedabfb090c28d7e05457e9ca784156c087b': 6.0603533,
#  '53da55e44c958421b1bc061855ed5a90fcb2e96b': 6.708387,
#  '5c639a19c011ad1c28d1799ac5e0abff2bc07fc0': 5.7496157,
#  '788a558aae883f6cf660efaaee512ffc777a1a24': 4.701267,
#  'cbfe3dabfa7b7d5bbc0e280a2c9e78b2c8d7897a': 4.4513383,
#  'edd08ec7c4960b7c14ded8fb50f1dfe53cc87780': 5.0348325,
#  'b47b77324e04dba99ec2fb2373e3286815afe1fd': 4.846053,
#  '8b34c40658eb3c2f346bc5ed8b28254831584560': 6.626441,
#  '6a7949ce54e841a134aa8bc97d83395c530c9400': 5.6486225,
#  '51b114d8e4bbb03dd1aeba4549994c14eab31df4': 5.5829535,
#  'f5e308166e10777c64133a4abe374da6d5cb82e5': 5.0460095,
#  'd9c114a0f60a995b59d19faccfbedad914d82f12': 4.4543624,
#  '8e7c0a1fb94870a07cb09b5ce8e4b90a065dfd1f': 6.1282663,
#  'dd094844ce8affdaae4b1b94f3541cd682220b11': 5.2154694,
#  '32b11db7a90dc88a102ed6c312353172823e2126': 5.619094,
#  'b12d981eca5081bf9747a3536063f3adb6273e67': 5.018791,
#  '12532db98a703e57cea6bb439ba8834d84efe189': 5.1221046,
#  'ad76f4a868c955303854502986aee07e5d39e4a0': 4.6590595,
#  '463702dcfb99ff528f16e7da951f57282f9180c3': 6.5444965,
#  '81e08292cae898d4e994e2ab66f87f71a263279d': 4.4973383,
#  '4c57f643242f1343b45d3f7568de072818cb647b': 6.026217,
#  'e03326a68628262036529f10743810973533f99d': 5.686836,
#  '1ed15237daca4ba3ffdb82957c0272091587dbd5': 6.9127564,
#  'd7ef28e1d155cdd9b77ed608e1bc822ae657afaf': 6.077123,
#  'abe52774cfd8d14e0550bf0943c31756e057d214': 5.74836,
#  '2a8d4a94ddeea9c375cba704627191c6dc023fc5': 5.096643,
#  '048657d2af342a45381de15d4ede1b03f53b446a': 5.9984417,
#  '692f43013d9a548168caa28aa108e3eb165f95e9': 5.2873473,
#  'e5699c121871836c2cd07c114bf11bb7cc10c17b': 5.137117,
#  'bbe2a4e4e94ae4066647536e580d9a75b8af096c': 5.8936815,
#  'c55f8f2bd6c81cbc52f7d208d3d56ae7e3d579f2': 5.4478836,
#  'a79b1630b9594f412edbdddb32d8b952e2df39cf': 5.096639,
#  'a68975a482dd873e386168853a5ab0f9fedc163a': 4.7832866,
#  'cda0d2c0c11f50b6dccae6f5ca2f00ebe28f8f5a': 4.96448,
#  '41176f14947fe9fc82a0d4bcb99e434e503fd4e5': 6.654479,
#  '1ae9e4aa7caba45d0e7b1dd6b236e1727a249fe2': 5.2793703,
#  'b840973580538f69650e9fe6d4085840b1d3f8a5': 4.4851475,
#  '9d03124666e2249a103e7a1ff31de338fd93f32d': 6.8704906,
#  'f01339a7a9de69e16ee2e68a90efed37af60b354': 5.4339604,
#  '180c0c25675fd493394c29456b2f73e3fa3e6b9c': 5.598752,
#  'ee9cd7b5383bcd7c9c6497b14a8a00d3831d5773': 4.4665456,
#  'f8185d3d6578b6fb2ad19f6c706cd009ee9c8d9c': 6.635025,
#  'ec74362f898f0189fe06313cfd7fba335092934a': 6.227226,
#  'bc80baaa381b32dba0e5ca9aa9f234cb757e9406': 5.881414,
#  '529b085665c9b77451b76c679d74a6776cd721ce': 5.4958725,
#  '39b0745480934209902fcbd28c85c9501c7f17d6': 4.4897413,
#  '26c7e34cb7a128b488de0c1e89c9349a55668169': 4.5018296,
#  '1fb4d632db4be218e01ff644ff0fc2b725f33200': 4.6050344,
#  '6e01def97bba0496db3762420f3dca4d7f264e58': 6.2187114,
#  'd2cc3e8b71c6eef80b4093959833ab292fff6f13': 6.9557934,
#  'ce592c55c668e77b2bdf2a4e52b6225c0863c908': 5.3033805,
#  '4d382487511f8ec1bc332b347565c8bf79d052ce': 4.5435567,
#  '368adb8373a2964976d210d9c3cb577d067cbee3': 5.6108165,
#  '5f068b0da7d777b684e3cbbf8e8181016760c898': 4.491665,
#  '0f71a0cf978c6a3a6c70a2c6bb963852b941a209': 4.606347,
#  '670d4f8b193c5f72a010cf7cfd075d97e95518a9': 5.11994,
#  'a0d75532359d7df0c1aabbe54c9ca186c7e41857': 6.2795553,
#  '6c26b1cc0c3bef7fbf0d66b5b48aeb790d17a400': 5.124604,
#  'e0b18ef5b326f0ab8f888f4a402884da5c182d7f': 5.0453324,
#  '0154b7f691032421233299d60845b28ea4f381af': 4.486351,
#  '5cbaa640bc89e65b61f678255c3a3d688f0e909f': 5.796811,
#  '7cdaed13eaa535ddc61bb673d2a042e6ce77635d': 6.343349,
#  'e304477523bc6e63fead5a647068fcd7c97df0ab': 5.7424574,
#  'ba571e89e0eda9a8643d08cf7a04c412aa9c647a': 6.494185,
#  '86bba8fe266ff72643357d269679ab40a0376e9b': 5.046646,
#  'b3209478d3740fbd593256be6bb00a374bb6e44d': 4.6776776,
#  '140f2636e1699a84cd2210f55204920509a955ab': 4.573326,
#  '1727ebb38e061c2ef07c36dc0dccb604d5042d85': 5.1377964,
#  '40b47dc90be74e37e2760ed8d7534077b640a100': 6.152051,
#  'e90cb6fda976556e886583eb36cd7b5f227c8999': 4.6539426,
#  '01f7e754b5a04e101c9a7c0ec90cca4278647f23': 5.677181,
#  'd7681062d1826c06aeca716e0aff6d5c096ac6d8': 4.44686,
#  'ece0847d0059cd72c1c4a56d71aa3ad7e98e9bbe': 4.7056284,
#  '7c930833c6a01a1b4ad4b8f3cd712e8b25f7bcaa': 4.741971,
#  'fdeac9a302d064c6fd0333f193ccb3b848116a44': 4.8500686,
#  '56c33973ff158f9a976c45e89ecf41630acc8ed6': 6.961576,
#  'b0521440832b3d412f702226fff89388fc54c742': 5.098373,
#  'e73822b31ee823f8dd1457b3d8a2d1aff4361bdf': 6.247274,
#  '0a4c545b6ce9109af95002908ec054b28b58856d': 4.906025,
#  'e961fdacda473ce3394249ab5e97f2b871fb108d': 4.6490784,
#  'e25bcb168b07198938a3507e74779de7a98e2e9e': 4.827677,
#  '42f1d111228aafb327ccc6896150fcce4ba8f1ee': 4.8568783,
#  '649aeb221772f558a23a8723d0e15ac856c0d7ab': 5.5602655,
#  '097aacb292bc9d66af5e05c78043a936cbad498e': 5.549032,
#  '189eeb0c996db5fe676f7b986312e40a73ae3f44': 5.2419734,
#  '67dd40b474b7c0501d03a03612a3b26808988643': 5.61528,
#  'c191f97f8f36af6de4f69d8d00854078ff1e0318': 4.789994,
#  '9a8b0129457a6bf7568cb3c756b3418617d43a14': 6.542126,
#  'c37c5f1cefe46565d793b505b64b9471d10dc94d': 4.5190926,
#  'c2013bca6b57849b9eeb1ef9e632cecfd10238fa': 5.0892677,
#  '59d54cff9f861d1021e9d07e59c583d831ef7811': 5.2142015,
#  '159bc69c675eb2cbd52ed9ef33f0b33b6293a316': 5.1469054,
#  '3484b44b161fa00c0b5dddb24642e8a23de504d0': 4.466172,
#  'c8154886c2714dc16d7ef90be38c13da05a44ead': 6.472438,
#  'efb03badd464fc4157018f714ac198e147eb3857': 4.6791105,
#  '7c28f60f87d23a63538b4c0fae1c8f74bcdead47': 6.079142,
#  '02c209505c2a2ba080a78295b4e3a3436bdda291': 6.5806904,
#  'a2135208e0abc6a849b10f75815690bab954a7ae': 6.5311084,
#  '2364345a6eaba848c98805189f729c654adb678a': 6.237288,
#  'bb4a6642b6789ea74c159990e812a9bd8d73dc5b': 4.476676,
#  '5e632c88e37992f65786f143b6253bab2f3a50f9': 5.604026,
#  'f555382d006bd5baf41ad5935c64ca32a2a2c559': 4.973437,
#  '3332ca99622ffb0751f1b55bd4f397c3d3e9980b': 4.5975165,
#  '087031d1dc424e90e4c6c5231d1c80fe036482c1': 4.822691,
#  'cce88964dc4423833778ab9d51cfcfd1f2d5ac8d': 4.898278,
#  '14ea131383c712737f8f0d82bd5e96e4907f879f': 5.538653,
#  '435820051c7286191c15c8f429f5be41766ba78c': 4.7413206,
#  '6fad097b04054c05bcb06564358944d9e3e80af9': 5.218044,
#  'a0397fb5f9a55f5ee749a2ee1ca72a0fceef7772': 4.6865,
#  '8a5740c26a1f67e49805ef7d86218c11bbb53ef5': 5.5069776,
#  '22733beeffe868623149d512c235611112c750cd': 4.8155947,
#  'd0a748ae3913052f3af7329257fabef8ded2c847': 5.8568387,
#  '0e2697df247bfb1c6b85a4b20fef04c4acea251c': 6.9527307,
#  '2108b34608d08ce278e32a29f1172de80e68464d': 4.762127,
#  'db22086ecf7a5a25a25bc085c3c7ba31d793e46e': 5.1163583,
#  'da9a4770797fd526d24c3f269725447250d4dc92': 4.6374993,
#  '10638f03f890c0bde047fda3b70404b48740abfb': 5.2295594,
#  '472a2f1047565d3b21defa16bf3e64ebad45f5c5': 4.6806655,
#  '3e0cba09e4298b739ca11723050859de4a357aa7': 5.2501845,
#  'd26694b8aa428467110c8cdb6e063e3b9860aecf': 4.5654573,
#  'c5064f66e93eda267f024ebd2a604cca8c4bee4f': 4.7395887,
#  '499702c719ab2b933a7ec2a997ddee71bd6d1647': 4.721097,
#  '1b54036218f54d1f50e2c32301d1dfde71a31709': 5.14614,
#  '992e5ca152598eed5d1cd48ce340fe6c8249a689': 5.4749804,
#  'f8a364a03843da0a05334e16abe661c0b5553a4d': 4.429325,
#  'f97bcacfcd9e340d77ba35d7b3c09e531d4ebdda': 5.3140645,
#  '739bf14ee491f075c6e710fcb8d7d7fdf31f8093': 5.1221933,
#  'e158a271c76384c48b74556891cb893064fbf048': 4.9735785,
#  'ac401ec3aa14fbefd74f4c21c46293b94683f4f1': 4.6124644,
#  '47ad1c0bed73db59e5a57b4219ea622e65345438': 7.121083,
#  '5b58f57d73693b94e3bcf34c53d465196489f426': 5.193013,
#  'a4f5c233a250ef3ac553f93728d4d602d1cc615d': 5.36983,
#  'feb6f25bfcd053fec37fad75ab39637170d2a0b3': 4.5138016,
#  'aafe983cfe645f9c5ad7e9b41b94f1d0fae1d43b': 5.4070535,
#  '4eb47b256457e92c588c1babd249a8e86300c13f': 5.5885835,
#  '9b62f5cc01c9d233a7886d0e9c6a7a8d63aa814b': 5.686471,
#  '6d0207464da3b8f81c65b310e4d617063b247399': 6.4340463,
#  '656e89f7ba3766c998c618bb9f5ee17dda8d7eda': 4.455895,
#  '5773d065285abd45c0bd8ff1e5d1ab41b6ff93ce': 4.789529,
#  '79c10b8a4c6accf1b8b6aa73ed2d31f7d3418fa9': 4.5672374,
#  '138e74ec18116d62e2bf92905a4f50cfca57b637': 4.5798125,
#  'af2b6b570ffbdaf53970d43eeb1d4293223d477c': 5.2693686,
#  '6c794a9c9b3b6ebbc551fe743cad66a729da97c8': 4.7422533,
#  '662b957b180f793832c0ba18f1698ce90da08c0c': 6.2194233,
#  'f77443e87810a3a5d0ef7b23b5bd0c935e4bec8f': 5.579272,
#  'cf5fbad62cad609eb4105a20a714d7a26e4778fa': 5.0036507,
#  '28721c6808857d65bf58e01a1a332a53370e2663': 4.6978445,
#  '89f1fd7af719a899dfc7338aef042329f299452e': 4.455446,
#  '69a9cab57cf3e288d1174bf26d76b28e3c8f4dad': 5.6621084,
#  'e3c2e9aa2ad9c0a90efba32e3935df94337aa957': 5.1573033,
#  '6511b37bd54edfd21622accdfcf5bb7bca1e94f1': 4.7896204,
#  'afd0212776cef464ed9625919f6e3939b881d1fa': 5.2220755,
#  '7bcc62a65987a0d9a78e9d939d9e28b54ac342a4': 4.862669,
#  'f435b3bb8d9919e19edb5f15fa77ba0a16b7fe6e': 5.268346,
#  '27badb1f1be5fbd792c37911f06591d2168f8d7e': 4.429359,
#  'baa4d108b2029ac3949245a10b106fd252b6c7c8': 4.6663966,
#  'b5fe4d51fc025989bfb48ab1cf307b8f49562e31': 4.4674344,
#  '2542f989669f54c6b5f562d004ad7c0a3d286993': 5.2320023,
#  'c71cd03f2da88e1b53eadf5e4b9c980267cb522d': 5.8271422,
#  '37b795987019d46ba3bef8fee6c2cfb35fea74f9': 4.680172,
#  '823225985f2185617c2e8fd4c0e14dbaf8d75326': 7.12804,
#  '449a957af92c988e2fd80ed8fd44f6fc5db4344f': 5.0020957,
#  'b1ef4d3edc0a8f1aa9d9207ded2024d11ccfdbd2': 5.3799834,
#  'ff8a65cd452b9fe696045b3a831027ae90a7add6': 6.1727304,
#  '90246c2d2d2a029ad76809df596c62501561a49d': 4.4852657,
#  '0b9fb950dba0077bf5fa17c85118af9a16feb90f': 4.852647,
#  '3a9f100af74b606d8e99f5c6562d5ebc27998f71': 4.464675,
#  '613409ef75923a012e105858a37932c129a08832': 4.958361,
#  'bf68cc1ec034ac4e7980de537a38a1f086187acc': 4.58317,
#  'c9b8bb170134837bd881ec26b39eadd4df55b0fb': 4.9728885,
#  '6e8caa2f0ff9527ad12dd54249d91f55696671a8': 4.565988,
#  '62fc215970df822ac45651639de2c9cef43330af': 6.041623,
#  '85edab6aa16b0fd88d92354f5e3f0d5d01da3dc6': 4.835343,
#  'fb9d42e383294c6204fa9feacbce437179d87791': 6.1429048,
#  '387bdbe403e25d838bafb6ade4b6edc4e924f6ec': 5.4418716,
#  '05ba4ed269992a818697a25471d08683b0dde8d3': 5.0671234,
#  '24bcffcbd9551a058b91f7ac3466e592c5612289': 5.364657,
#  'b0b27a8caf5952068547fd43a67780a60941bd8d': 4.7957973,
#  '8d886dd95a24c6959d989e588d9ae575d9cdebca': 6.677291,
#  'ddb39a102abc4598d9cd98e98bab8cbaf6d2e98e': 5.0662293,
#  'aa15530259b847900c4c5b76d60016a46d394d16': 4.453191,
#  '2b5e829fbb0b114be37ab5404bd015b8db2df39e': 4.9601665,
#  '1e4c7225480b6d73844a61b51b2764d43504bf76': 7.1084046,
#  '74c96df88a2095baf6b4765be7a5cf06776fe590': 5.0074844,
#  '0cc8c1dc67e6beda402c01b8f164c42362900afb': 4.896488,
#  '06ca48b82f2c21a5c7f39e6142f9326172b676ae': 6.51392,
#  '0db29db3e49e1d2a9dfd3220f5ad4d0c11740345': 4.884738,
#  '88cd011d92692320df9eac0c782b67c8e44da9d1': 6.292599,
#  '3024eae15140a6937a8a56ad2d3b8e1910b0e7ac': 7.122133,
#  'b562f0d460f36478f7a3ff3aa7f2a11f5e8252b7': 5.0401616,
#  '19c6183bcc25a1bb7e84eae2de0bc78ed0f96038': 5.122727,
#  '5bd9f3b040827ff0bc978eba9adf27a53dc2a837': 5.4137917,
#  '2d31846ea0db8b8860d5368d6f51ac2a7a7d7848': 4.6371183,
#  '959d9571507e9cfe65684e5717cdf223b12a423f': 5.943834,
#  '1c2ca209be776707e2491e1a9dddc71ec72489b0': 4.5139318,
#  '4bb413a666608f49d713ddfc64cbc6aa4b6ada6a': 5.3970175,
#  'e5ff22f8ed430bf43efa98758bbb33ea5e74ff66': 4.985245,
#  '7ee6e596643c69e5fe7493fec735ef22e4425572': 5.476339,
#  '70985e46a01e875ae1608bd5eeaab52d80ee6090': 4.8895135,
#  'd18721b5c80f6bf62f11ba73d0b9076f532397d0': 5.55525,
#  'aed01942fbe259a3f428677cbc19680760913fdd': 4.6596723,
#  '3ca633bdfd47d500e1165b6743b66bf39c88b6eb': 5.964959,
#  '90c51c376c0722a38eb69bd76dc2ab0799b5c6fb': 5.8250923,
#  '54c279d407156e6625ff0f0232e10548b99c84ad': 5.092192,
#  '25a922426841d9ae2587ddcf5017195824207bd3': 5.106055,
#  '23ee458901ab563cc92139054232674e4ab20583': 4.4549026,
#  '1975750f6aa2072319b6bda3306d493ef6a24e6e': 4.5420976,
#  '58490702a6def332407c6241f9880d2404a77964': 4.7966256,
#  'd66dc49712f51e3bd3d46083337e3c8c82f8fd3e': 4.5273886,
#  '6a0daf3f6df5550bd18db3966c15017b6f872aea': 5.1456084,
#  '7e922993645cd22539d9ffe7e91fe16e9643aebc': 5.3236504,
#  '35f2077ff8bac880dd74a85d31a74d33d4b14987': 6.8029475,
#  '764c39b55afbd2ce1b4ce4d357fd77c09416bcea': 5.4565034,
#  'eb9e2924c5503415f83ce99c3e6fed0d69a9fe59': 4.4620533,
#  '556b0d5b23aea7874291bd598aa249503bf6e9b6': 5.220669,
#  '2f05507eb908ab4485e72ba08595cf406bf8bcb7': 4.455529,
#  '99b34df818c8b44964c6583fccfe8d6a171dc312': 4.784488,
#  '871e482f0c5a889fbb722b62819f7945f50ff0c3': 4.50836,
#  '85c5aee1b75247d5581162045b7f6d35498a425f': 5.414698,
#  'c5baa86ecff3e5410fb59074a32f73c90ffdac6a': 5.382334,
#  'b892db10e616121692b7f1839cf3be449dfd406c': 6.950316,
#  'b9527f83c29a1f1aad78b1011fc39b82328e97e4': 6.502401,
#  '8e593eb6367d350124aa3930187594925ddaa869': 4.6889644,
#  '35118cf2055cb81ec84fdbd07f20500546310785': 4.5015955,
#  '7f8f0a01df00811071d5d180a9465ebd9343d2ff': 6.1112657,
#  '490f8609a78c7af5d7e8be72acfad9cd3502d536': 4.476681,
#  '0ff747c632e69b4850b38721dc63425b90ef0866': 4.613352,
#  '71db84bf87e39facbb2ae44baa4244c5bf78e020': 6.2155986,
#  'b758a12adbc41cac02b0c862577fff362b886455': 5.039601,
#  'f3373cc8a32867f89ceb356ab5709185426b897e': 6.281677,
#  'dc028f302a3070877e73a3caeb9a627f13009a58': 4.4764137,
#  'bea18254c3c0f2252e53b3a62fd6e911dabe19a5': 4.7618246,
#  '878c485b1fc9003ae06b1b6f008fbf431a035781': 4.4851108,
#  'd8b28ab56bb4aff3058afc6a4edb88896fd25f01': 6.386354,
#  'a5aa0d1d50fe3b081dac9c2d1f782926bf21ca38': 5.222846,
#  '919849d6e80e9e368cbb92d28d33572c31d694ed': 4.650764,
#  '604dd3863fe92f20c9c53cd010a6f9c54d3b0cdc': 5.261233,
#  '7a4236a5ee885c2de134c29a2510eb60cf7b73ae': 5.640932,
#  '55090bf24b17ee6284ef4fa49ef656bad203ae54': 5.1809807,
#  '42579f1ae08d53999462dc59bbba628132305fb6': 4.5202236,
#  '0391a42767cc05f74a9337a96580ac7c28d863ca': 4.7939963,
#  'be48e490e704e0302af4abe5ccb554105fc26e75': 4.471864,
#  'a38ed8a6a1b0cea70b15e97ccc96901ca64e4a75': 4.9661803,
#  '22fdc3b710f2d9ffbe56cdb5eb9be57495332d9b': 6.3933487,
#  'a31823060458ca7b758d2d8337a9cb170a4f96ea': 5.0836196,
#  'a9a778cb9f40cddedc616663f21daf5151b17cf6': 4.6268687,
#  'a8a0e95b4b6108476990d3b88560d56aa843409f': 6.5503316,
#  'c303b3a27fc61ef982ac55541341e5c500b61ee0': 4.6152124,
#  'f4d2bc6bace5aca10f1367a74c26bbace19a4fce': 5.171141,
#  '27f90b743a00de39d575363915b26e1cbe2319df': 4.962075,
#  'cff31416ea355d632587db1bb82cf84aa43d30fa': 4.840739,
#  '1bfbeef8bc1a8f6c31537b96d06527a5e3eddf01': 4.492261,
#  'ca3e86d243696fe31e4c6fbf3abd1f4fcf731cba': 4.4902844,
#  'b5adcfac11e0a88076ab3c7269b2d50d3540435d': 6.2877917,
#  'cb11c63d4747417b1838ae7c7e3bb358386ab86a': 5.0945997,
#  'e78e8c3801b92c43dea95c92c16e4973e6eab5e5': 5.5790324,
#  '4dafa9bda515c961e23880a0d2d09ac82e23a73d': 5.1126966,
#  'f2d8ed5b1dff6c13c8a2f110386fa006ac62f7dc': 4.466494,
#  'd487d4b11e4f5555c91105d37d267a51c761fc97': 5.1326084,
#  'e9f87fab1b95be096a8495317ead9130206a6b24': 6.430316,
#  '2c3938e4150a0e86078d5749914c4599cc4c2157': 4.501823,
#  '639684130dab4f8056e7d800dbfd4c20e5ae4e2b': 5.0436835,
#  '9c677aa78a8b86a4663d1396fef1751b01ada6ef': 6.4116087,
#  '21deae2a9d6c7ab0066ae706e49d9f4dba48b259': 5.7176595,
#  '37312bc6280b525a167ef1e5d8d4173f3c960133': 5.904247,
#  '9f59b393d3c0bc8d721637a42ccb4c2e76456295': 4.867169,
#  'e4bdcc25b5deecfdca3a95b457682b27e790bbb5': 6.584446,
#  'f653e0dad869b3f09ebf39cf93289b0825b1b04e': 4.507027,
#  '9eede2d97fb02c74e2358834d4bc493d79e7d1f0': 6.5059237,
#  '07aa021c974893ce3ae0786fcc7cab343eca199d': 5.4856825,
#  '0c446b302d002ad233b38f8ffb119ad33ac662b4': 4.9094143,
#  '3fc579f269cb4726a1948323777ed1726197d5c8': 5.2722573,
#  '38ee3d82cd446e9af8896d6c1817b8c5944863a9': 4.800724,
#  '7b28c62a78640e55460fbd7a1cb050fba21dc4e6': 4.8434944,
#  '532fea0f1eb4082a248e21fe2005deb49caaf84b': 4.5201073,
#  '8e5967f90ff9fb93aa2840fceecc537b2e8e6ff3': 5.447019,
#  'ad22977f2d0c248fd991e4ab469704682cd3e910': 4.5712805,
#  '348913e0dfe0d9e46b07f06dd245b7f21b08b34d': 4.829365,
#  'ddb8ffa5b5fc18b91a4dddd2c2094305a8fe38b9': 6.5210986,
#  'fd02b4ab6ff191d02b06839b12f3df33064f36d0': 6.508689,
#  '949f402410f2f8c5ed409e2fda9db38a6f2c5298': 4.4188595,
#  'e508e8a46e691e508a064b122b9e0435c9253647': 6.6198716,
#  '3345a917deeea1e542ea417602653862e692bfc3': 5.4744606,
#  '4b49819df02fb554085700308b134ca34a69d84c': 4.732367,
#  'eae0512b0982ff7481444dfe3208ad224a99a740': 6.314772,
#  'bb6e1b990b6b96c26acb236d375e9777c9f1c893': 4.585157,
#  '070a3eb8d5925bf142a2f621016a42725adb2b09': 4.5113134,
#  '5cbd354b76d6fd8bec60f98f5ded9bf557f576b3': 4.699481,
#  '8c66337da6eee00b42446d33f46ddb24d5154a7a': 4.720405,
#  '4ef416771317c958cab52ea732da91f356bd8e42': 4.497486,
#  '4ddc26ac62e01252d7ab5ecaa11ad2f7295f94da': 5.800169,
#  '72dcfc621cd24b9dd07368b2e2d333e5c5ec1370': 5.6840544,
#  '05bfa12f1d67a52f01114598508f116d94b061f4': 5.1663175,
#  '29a799179a3fb3e6e85ea905d751570e510ed2f5': 5.901095,
#  '4c5ba926cc10019eed4b99dcf5a016cb135f585b': 5.8529077,
#  'a9ad1008c0261ed115802107a344382e8812c248': 5.548278,
#  '5b73248f15beb65498328bfe80a33f6e22171518': 5.7789974,
#  '7aeef2eaa51b553443f57e0993ed09a3823e196b': 4.629053,
#  'f062009ab69e49411f2d5f2848f1b1948c078877': 5.101045,
#  '5f3f2774e4f11c6389ec8f542e398af657f65b5e': 4.7738543,
#  '9d58ff54a944a8d0415942f6bc79d5bb2093ce0e': 5.9508677,
#  '6e9f6950b45831f0ea2270717151ae48f8b73c6d': 5.43288,
#  'a04ade6b0cd12a56040683af6a4ccd37be8ee6c0': 5.418161,
#  '609150249b65824be4fa17de32727f0d1275ff6b': 5.2323627,
#  '9033bc95a8c1f6513eab2fa68ef51a525a0b5cfa': 6.2530513,
#  '8b85d9b73e0c629708c8101d5c1bb5b42c8a96c8': 4.875808,
#  '2d6bc5d67e41794251f5b0d9a2e10e91000e63a9': 6.482605,
#  '106cb3e39fb76c4f2f77e798008856075c0fb877': 4.5552893,
#  '96fe167abe623412f411b2ec8d75b89342fb327c': 5.582389,
#  '22860a7ae90acfe5743259e2697e4789f51a318c': 4.517014,
#  'b8a8395efc058c0f0d11bae9903f69e9f0e31ddc': 5.431309,
#  'ed0be1f544478d6b41c667ba1f04618714a03e4d': 4.658078,
#  'a5ab93028c80965da68c91e81de77fb5d531269f': 4.5079045,
#  '1418b45578164614ba3af8aa3c0c1094b0e321b5': 5.5238295,
#  'c53038072a7b49e334a3f89c25cc90bae76f7606': 4.6467004,
#  'eed9c6b64cdaaf79b207c6fee015dde926f4f09b': 6.998411,
#  '3da1af69d5ae11bb92f49b3ad55c6dd2795165b5': 4.520352,
#  'd8bfc9b00c5ed36f14f392ad06fc28fc8e9f0e49': 7.1245174,
#  'bbed0439171266891380ce202bf4040a8b639a3e': 6.0306697,
#  'e5803eb5eb7b42826e56387150409bf3d769096c': 5.327738,
#  '236466e51855ef212f8c9e61cbdc03551d38eb13': 5.5955462,
#  '3bda81df100e50fc1fd73a6605d0f81b10fde079': 5.485433,
#  '18548de7c4f6acc95f9d8408b72f8739ddc2da08': 5.8846617,
#  'edd11c1c489d0e06183d6f8ea5d9ea9d44971cd1': 5.307724,
#  '1976b4161dfb6c2669cf7e1a11ef9c6b1a64ef0f': 5.180446,
#  '8a9733e7f2bec274b0d544b36dc844eb950e4ed6': 6.027729,
#  '4367aacb43cbef21d70b00edd2c98aece3cf1073': 5.4953647,
#  '9bb9afc6d008f16b69458955b313b41f3c9d6d2a': 4.7588224,
#  '09be3943467c73347f17bbeaf7a95cb450668e60': 4.613845,
#  '1d8e9f1962cd1166a9467a3c3ab5bfffb1d71ba6': 6.13645,
#  '431e91bdc3ce34cb65760ee6bfeb32b4019d5667': 5.527471,
#  '1131465aa22415c88d9d210edcf5b182191523a8': 4.9789762,
#  '26cfee21259015c3995fa0579f08c7e38edf9c58': 4.5487742,
#  '95f58c8a9ac4c360d1a71610fb2d1f532c30dc45': 5.4165006,
#  'e757526df279968c328a83d2a5e23aae428d9ef5': 6.267445,
#  '31b9c7e1a5ab1977e806de69fa13bf4148e7d008': 5.7419295,
#  '6ec742045a18fed340991a6b9f0e26ea1e7f8b9a': 7.266546,
#  '4d8363fcb5e4354c121f6f81fda34b3257d06be1': 4.908655,
#  '400e07e98976b7ffb81c8afca6936c0c248fcd2a': 4.7781844,
#  'fc375eea257bf856b94a080227aa0532929f1589': 4.8119936,
#  'c6948d78e860f6dd72ec53dac139440d6629057a': 4.5008645,
#  'ccf98a80125e83ee9c350713b3849a74f50bd3b8': 4.4792624,
#  '32b6e19141d02c22d0208197fb6c1ed1f8e967a6': 4.6040773,
#  '4545da53467208a2ccf02ca68a7360519fd821fe': 6.7981963,
#  '717f529f0ef635e99f780ce01b44ffafd319ef27': 6.349994,
#  '52a4c293c2aaf4ab15b186059a33dd2359b1254d': 4.4818363,
#  '8a0c0a43af8339302644a6ea4914c1986d51c2c3': 4.8762584,
#  'bc8c7eb7bd898581ea96d46f668cd82dae09db14': 5.4696493,
#  '826af4aeb84c300e579fd8e06d4455dff9b3ea75': 4.558235,
#  'f98b6ec8f5b8dbcdf725bf60b435aa379db8587d': 4.649537,
#  'a7ab49f3982cbf4dc15835e22758df15cc6b0a1c': 5.218622,
#  '7f9b1f360d074576ec6050b0f2613aebde7e30f5': 6.6345525,
#  'd802fdd3954e0bb973dd084b1331744981a540fb': 4.7532134,
#  '925f306b5a0f777d83334b8d633c2052af3af050': 5.867417,
#  'e636f5dffc08bd1af122ed1498af18bb5072ff8a': 4.496405,
#  '9e1f15b6feee99b98a061c2e383ff515ce4b7e49': 5.9130993,
#  'a0fabd9fd675173a3f751abac022a94363998f78': 4.6739826,
#  '580112262cdf5377b1ca78dd87a587aee74fb92e': 4.50996,
#  'd776262a07ba7dcb6805d33be7984ae3671d7f26': 4.892839,
#  'dc5affbe583285ea9bc37ca4cdaf05444b023300': 5.13249,
#  'f43d772f7dfe94dded993bcf210a1b4dfa6b4227': 5.185027,
#  '2078bbd6ea205b100d10b05cb3edc61ec89f0d4f': 4.5244584,
#  '90da8fea32c8ecfe8ce22fa9f762facc4d013029': 6.067105,
#  '4f950db7a60d10f87e3a88efad1c809c917dd5f8': 5.1497197,
#  '63e1cb3575fd1fbe7b399008413c4ef4e7cfe91d': 5.575286,
#  '6a1404e71bc80af723de56325627cb35d80c83e8': 4.5465355,
#  '1390dfe686011bb37cf85ddd7d6b2757aa53e034': 5.738577,
#  '0ff79d9d33a1f22173587e4cfd161bde554ea8eb': 5.8052874,
#  '71ef7de09f341d819666624c8a905a631ba94b35': 5.182143,
#  'b6004217817a63f9bc65bdfbc18cae9b9a00accf': 6.6822906,
#  '552297001acbe3ed11c5e12d0d51f5018340bce6': 4.996031,
#  '62921e06207e7cdcfdba9cab990d685153cc9825': 5.223177,
#  'bac673db15d512f801dfc2bac8290b3cacd7660a': 4.4993877,
#  '19d62b9579d7c7bbe2b98994cb762e0aad7c0688': 5.0199304,
#  'dfbc9849f57b70d63552baf04c7a60f2beadf636': 4.5438094,
#  '039af4ba77bc00ac353e913d7175a3be7adb2a40': 4.6242776,
#  '6fb42ffe5d59dabad9cc3af7c0be15ca352eac25': 5.352635,
#  '1513242aa79afbcf629695f53160b6142f33d794': 4.584278,
#  'ce7c26fd9f7ef6d8220f3dbb27e9fcda6f6f56fc': 6.879374,
#  'e3ee23a3fd23c8f47b9c8a61e50c5bda5b34c9ac': 5.105329,
#  '3ced811839a7d74ee9f2758963ee3a373f278daa': 4.509319,
#  '50630c0e6f249ddc28d67054e7fb135ba34d7983': 4.7468386,
#  '3c72ba2dcf27873194933aa12e1534d9114bcdce': 5.466395,
#  'c758a832797096058ee8c37ec3bc4a3496f43626': 4.4968853,
#  'be7355a1d72fce09a53c73bd32105aaa869b38d6': 6.3536158,
#  '38a5244ee07d94f1e1c1ca6b28e9923ddd1180db': 4.4646716,
#  'c19a2e458d9cb782b511a66b60a607b5b2d8a15d': 5.164074,
#  '6c7b9a6a746f5241689b11b79459b658ba43b129': 5.196904,
#  '64ab6dbda39869d2a129fed0a963a7acc6d069a4': 5.237574,
#  '35239a1acecf7870e015b2bd2461af048c2fcc9b': 6.4830594,
#  '474c047fffefd0713ac99c9b73c8cd7cd135b1b8': 7.0053906,
#  '3f365afab50f2991de32bd9e0b54a0a3405a5bac': 6.3106117,
#  '91a0cf34d8582a676aaf42743987a4d4f440edfa': 4.6927643,
#  '51c97e895b4218d0af2b5789a661b9c85f2a6418': 4.492114,
#  '1c523015d01f42a27591ac33edca06b1c9dfaa15': 6.049793,
#  'e97a74b48648a967326c651a99429e8277e663eb': 6.0957866,
#  '15e5828a014b1f693b599ad227cb0bc056b4cff6': 4.9190664,
#  'ae34e4cd222f8a16c5a0916e81a048abd15e4771': 7.234558,
#  '4e39d624471d29621c174d2878454697d1849205': 4.650723,
#  '69c5b14d2ba899bc604090c4f08aaf5b160fd0ce': 4.8785844,
#  '89af641b2bc4265a47acac87182ceaa8803112fb': 4.845519,
#  '8044ac4e0b6ecc1bdc3879d6289b4c22573ec9f2': 5.355383,
#  'd2e62b63a85b58847ad547de86934d9ef14fc7d3': 4.5495963,
#  'e25c135b71f4a56f6319312c85307b2bc0d2940d': 5.272144,
#  '5eb03bd6c4450e6aa25344f6b54d2dc43e62e4bf': 6.316858,
#  'fb9f44827c55b47f1e6358ee1d7b99c2bc320fe2': 5.3590493,
#  'f55e826ff8504300b392f2c19ef24fa1514d658d': 4.9699397,
#  '8dba39d5cd05e1fbda7b55f0bd8884ae3c51fdc5': 5.042178,
#  'd4df440463930789a99112ff7a3a024691a237cc': 6.3950086,
#  '38fda66bf7d148ac49cde195bb52fa0dfba5607a': 6.245506,
#  '5ddeedcf5625156ffc7de94b13bc87a38622dfbf': 4.691706,
#  '57340cdab6c749eaeccdd22528d3fca08b57c562': 5.7127695,
#  'efb0e4860ec4641cbea15c559eb7da2588da4e3c': 4.7703605,
#  '2f08bde98a84c80bcd5352e90a59ff04960e1436': 4.484572,
#  'fa9888b0b79c6a38179cddafa97032e5bcec7c95': 4.620103,
#  'd58650b75ce72c7be7909117ac94f95dd907c585': 4.573007,
#  '36cfd7d8ff21d0c6ba794d014f0d10c0fa0aaefa': 5.6457753,
#  '99dcbcf0e20d575cd062d428f85c442c8150dc05': 5.6982512,
#  'f8db891789050c56329258aba321c04c4408cac2': 4.556057,
#  'd0b95def721cd15c0bfdd97f65bf4ca002fe5024': 4.860584,
#  '42778c9928c0912f5f26f80df33c3bb0e087b7bf': 5.1937685,
#  'c82670c3a910b7e98cd877af963e495425517913': 5.213972,
#  'c562de589f3883bc637c9b9320ecf27399d5bb69': 5.5130405,
#  '21f6b3c7353afb7a470026799c53d56a25d2cdaa': 5.038096,
#  '985f6c688731e41c7501dd919351fca792a232cb': 5.7884555,
#  '1ee6a390c536a0bb5b208fb57d76095f00f09e48': 5.3343816,
#  '9eefa8e7e8f49ae0eccdbc53f93c5255cbc25963': 6.918705,
#  'a3d79395102ef934bdf2b627ad8fa651ec3da671': 5.8707714,
#  '7a5573437640123c4d13595d32457907add21834': 5.1874967,
#  '3e48181e44036503786b476ddbc8042f6e599bf7': 4.632571,
#  '2fb3a6d118b5981ac09f42e2ffe6f812773bc023': 5.022548,
#  '5bfff8397cf5d5b096b6d6125404ef25a3b66798': 5.4609985,
#  '27bdfc789758a584d145b76f3fb0f7f8381b4a15': 5.0299196,
#  'f4ef57b52d87393487ad017e87ac267d506800af': 4.491817,
#  'b988eee45d0638c7257366e0ae0e0a88b44f2508': 4.621447,
#  '49afb98e2fa22118fbade44c54a2b14420b97eb5': 5.6686625,
#  '533542a8d65b23212be114716d996582bc5b988c': 4.57856,
#  'cc287a3c2b46c4d873aa87f2f0d6d4ef63e84e66': 6.792208,
#  '057825a77f915e8fa5893cd224994b9e8b772ca1': 5.3997307,
#  '0bea94a4cc8c3ac129193c7aee9cf42690abeae6': 4.8526373,
#  'd55091f4c1f4d70a53dff9e187c9a74e5657b2d6': 5.5061245,
#  'a31c07088e7843014d8001488a5f1478cbea86dc': 6.56922,
#  'ba5857c95a5f2ac9f08a27383c939f8bd9b77268': 6.0835843,
#  '35f9b9ba34b8dd11554f924b98086252c56e8f84': 4.4563212,
#  '02748a4ad95998f394ef629361f7334d1972a665': 5.4961195,
#  'c9bfb1d66092938a5c42c08473abbf16a9735367': 4.6773925,
#  '0ce662ea67af92400f6638f9fa993d2c73d5d425': 4.4940643,
#  '0db61d50afe2854131ad3619b672696a24239242': 5.656888,
#  'c25fc536cfbdcfded271e679fbc401d0e3a79e8e': 4.426946,
#  'da1549af83c813e5b53a4e4c0d588fa0099e3d3d': 5.12583,
#  '70a53ac22cd1dd79d28eeefdf07f5587c0bde068': 6.120672,
#  'ea1df209614810e47a0fdb425da6b5830b122aea': 5.4751897,
#  'f6c559913c18eff8f3df69b492a48288e23d363a': 4.94762,
#  '6302ac23d5cc632640b374fbf07a1b6019aef874': 5.4186764,
#  'c3937e2ca1220c3884c9713ba1fc688c46227b70': 6.6312323,
#  '8f1d65d55c784b4e0965c1a65f071c7f0c41b848': 4.8157554,
#  '280971d1ead6a1b9a8411e6451fa60be477ed494': 4.5001483,
#  '37cb42e258f5cb923bc4123c3177de15cfb179fb': 4.851308,
#  '0882349efffacc09772793a277de41375f440297': 4.651725,
#  'a6c51d97786f5015f1a7dc784596f05661e8d70d': 5.1229253,
#  'c078bd7d16727d6b959b5eb34de61bf619e5643e': 6.441833,
#  'e04098d5f3add3d9f721aea871c7a4e847efa66c': 6.225775,
#  '0bbe6b732f0526ed5761db322828f7931b5e97ae': 4.6100497,
#  '0e2e4c7a77cafe49970e6d856cdedce252a9fea1': 6.573507,
#  'aa55e7b97dcd12635dc0eaaa6fc27c41dfb02526': 4.800428,
#  'e6f7508602187e2b737565211ce23b35ad27f253': 5.3347783,
#  'ad7bea9a1b1a1be908530d3543ebf3c537a3b376': 5.61816,
#  'afdf9ee6612c1c884cccd3d6ee9507fbb3c8ab08': 6.840227,
#  'b3a1b78ef6c8ea2ea306199828b74ddc771e2d24': 4.6720467,
#  'c0dfab2fa3e1f442cd870ac48af4743916a26703': 4.4810057,
#  '6d0482601e2ddd6059956de1907612c463a09aae': 6.7738247,
#  '18cdb6644ba8b74afe655c5cb66f204f6162968a': 5.408475,
#  'ff8d8faf64ed8a749d230e1a3bd481788d1eea53': 4.653368,
#  'd3ba80b2a6fa382c4b17cc8579aab55769de6959': 6.398796,
#  'af2c0e1d7a02c13e73663d09a844a055d00af450': 4.4862227,
#  '7ea0ec634f4fa50e2f257929a07fb6ba844c352d': 5.5622697,
#  'ded5ec05dacfe00b04f5f1164fb680b0f8a4629b': 4.552229,
#  'e90dc490161f9e2dac55b509fac2344c90951642': 4.5176563,
#  '694dd665c6314c30847554d0323dbd0254ff891e': 4.562812,
#  '445947c448a4de035627f77029f55f80ef36b821': 4.5292287,
#  '86bd430f7c971ed740164ec97c6ba12469254f20': 5.660251,
#  '9fc0a49c3d282f6c3d6f890332d39e375fb9609c': 5.311048,
#  'abf2532f83ce7313895f32fe6d03098bf57eb535': 6.026319,
#  '3fc9f65c771b35eeaf63cdd33b256a5e042ba370': 4.573893,
#  '8e91ecb6bc72941a1d883f9678ff6c23861d2e83': 6.44953,
#  '39d485bfa0f86e2c32fa34a6198611156df22b27': 5.2502384,
#  'c921fcd4039ec56ef8149d1dab3b4119f6be2d43': 4.5291433,
#  'f92fe4030a5c73e0963a2162fc63e8db1df75134': 4.595681,
#  'cdbb189634fecebff8395744e8e9c392b7445516': 4.8182755,
#  'a220f781c68d72723f7fdcda73c4204eafcd6288': 6.1379848,
#  'b580851de10dade8738f4f46961c620aa2e91498': 5.580025,
#  '95408860aa889f71b0730e94560167e3c56654db': 4.5102324,
#  '8482ef4f8c603aafa8a188d7e0ca14d97dd2b3ca': 5.5189295,
#  'ac438e6ac47cbe5cc2e73ebe4f28f99680f30340': 5.1423216,
#  '7418cff03452cdae898c18c001db0e7503503b00': 4.455238,
#  '6e11eca0f4f32b59397d93264f1333ecb2c37ae2': 5.2469096,
#  '56610428d7e21a7c032b745721294c88965bafad': 5.5225687,
#  '1c9a5511f28d93b30d7a3e0e2fc05e7a51f2e9ba': 4.493477,
#  'b84e5a85710ae0385d542dee0ff5270a8ed78b6d': 6.22237,
#  'b6c7baccb12c09057eaf49a38ce24525e1131662': 6.751029,
#  '66416b06f740d7d44f1984350575a8def8e7d631': 6.6683083,
#  '0c5a0a0150e7b1387ea8d03b19c56948b7d574dd': 4.4424553,
#  '374f207be8ac1668a74326de8addb95341156858': 4.8469973,
#  '47b106d97af92f1f88ae74ad9544bd2e43187771': 5.960619,
#  'cf82417cabcbecc04a636082fa4d7fabfa3f5e51': 4.782718,
#  'ca4174dde54d1968145248711cae256c46787a86': 4.6491933,
#  '75ee18210009ccfcba525aed4d600fee5d12482d': 5.5486417,
#  '795cf170b9dd3a71df65297ca21bba38723b7928': 5.7822905,
#  '65a2175254a7e07161ae58ab21127093889bc5c0': 4.633196,
#  'daa0432ea8903c4fbff68e553d4d44309c2504db': 5.1764026,
#  '9caf4533e96c199d5c2323f77d552cd543c515cf': 5.711451,
#  '1fdc19c5f4c7ef5008b3194ab95470a10d1dbe9e': 6.002613,
#  'eca028012e306b338eb79b3d2633f08ba26fc6df': 4.5330744,
#  '6a94da6bd7a85d428e37af0e499acca9bcc43e1e': 4.9498854,
#  'b23918f16e2b147e3badde51354aab4f7d0796ad': 4.525738,
#  '25b04f9af3d3b70f0c72ec495497f3573aeecd21': 5.6528115,
#  '59deac6f278a411d89c9775a0c9c58f1d5df4957': 5.25304,
#  'f1ad9008c51e9eb16aa0c1fba7d1ee4b6a38e2d2': 4.5407085,
#  '41d3aa3e6599db1c746ffffe0661cc4986871b9f': 7.1723585,
#  '79eb71db6341ee2742a7363dbc943f07a0f9d880': 5.620497,
#  '3257bfbb231b27b4c50282fea546aac72b40eb2c': 4.497737,
#  '0f847aaa4424ef2392058ff66bc8c238d0ecdb91': 5.425736,
#  'f665c5ffdd5b5849cadeef2702eea970d57472a0': 6.491327,
#  '21379028b352584151739b11ff06af67145e275c': 5.539077,
#  '6b549ae42d35c08f1ac0648469914a1e0254b1c1': 4.8311634,
#  'aed372bc654ffcdffbcd5f481ff67b42d94e1e1e': 5.247238,
#  'f5fb636d000fa87ec3314e1d62d5eb8e19fb1595': 5.552053,
#  'd1c4399d79ee7aaf32ca8a8e42184281ea348b67': 5.023788,
#  '93ae1eeb1359a8d33bc59765f7f037f7ef967e85': 7.2427177,
#  'd72eb75e4afcbb2985890b3a892bcfe022c01834': 4.5043497,
#  '2426da2f7b13722a0bbfd787cbef54ab874b4ad7': 5.31259,
#  'd031425ed171494b27eddb2f44da4bca5c83f63c': 4.8313975,
#  '883fd1ecf1cf8486cc74ac50cdfc53c7cfba667d': 4.480218,
#  '1b5b5795e3f5283da6ed9849ffd1b54df40edbe9': 4.491463,
#  '7bd02883b0b019eec879d35262bf1b506f3098df': 4.728666,
#  'f7a298e512fb50c8daacb0756207e9ba25495450': 4.7479277,
#  'b4baf1671416d9eef30a14281947e9cfc1da29d5': 5.5403223,
#  '82e6ff47381bbf14a21d877cb0bcf2285ffc85f7': 5.2269363,
#  '2326a7457ee5c7ee4a18af1fc14ebe5aea0d19a4': 5.0466504,
#  'beb6fd5266af49b25a3062eb16064093bdf0b9a9': 5.5402665,
#  '1aefeecb46185cd080ae54150410f31658bbe5d0': 4.457649,
#  'eba87a051ca856bfc72f165055e9dbe4e5b50f33': 4.471821,
#  '7c2a8c7ebb00e26a9fa5d750c887326272d591ad': 6.014273,
#  '52398efa29967ff508f59f4539fbd733293fd6cb': 5.4268074,
#  'a8bb087db97d9490fc818714614289b2a1ed2da9': 5.172081,
#  'd274ef4a44557374881f07ca2d3511cd56e44e1f': 4.4835515,
#  '127af31b09eac5c5cbfd9f18ea5c3e9cf1bfdce6': 5.661385,
#  '58d9884ebac621cf1b59a4479db8ceca517f436e': 6.0527945,
#  'ab069fd2d5387b7a6c619bc9d56dfe6d446464bb': 4.48005,
#  '01fc154094598c1398a040ad5665dfd06eb7a7cd': 4.865978,
#  'b5b8dee29cbc59900f337c56bdb04f4ea6ca1512': 4.6163006,
#  '6827296d8fb93b5440c93cb413b7a9f6975d4f75': 5.830036,
#  '6dba8d9df77658dfc9fdc987d2ec2d9c4cc9df60': 6.627472,
#  'e175e23228712c7f87da38ccbdfa63e2cca1aeff': 6.5594273,
#  '003f8a76cb823eb7c58b6d052c57a8933f9275fd': 5.4592695,
#  '016970134a1f5b743b4c844f95deb5f8e9c9bf6d': 4.4352384,
#  '40c30e4fc799cf79fc39937736cd952135ca7d23': 4.4773655,
#  '861094cfbed61b27c49a7e6d9ddbb7029c67fab3': 4.550675,
#  '81f49bad2f317db481adbead2534e9a5ef8ccbf3': 6.163782,
#  '6c29f62d679bf2c4bf6c276ac209bc40f831e29d': 5.305907,
#  '5ae71c3ea38a123e2022a6cd0eb99cddf22270e9': 5.769657,
#  '3aa147344f7bec6076e2cdcd1d609f91c38adbfd': 5.107881,
#  'c5d6043151ea83855eacf7e59aee75bbd898f505': 5.82917,
#  '7c9a20534dca28fff5d6e768591119a65ff6c80f': 5.3199983,
#  '577e411d53a6585bcb1064c82bf00d7d8cd473b8': 5.3893914,
#  'db740b50470ff8c8b1840d8dcdd993fb20c5cba4': 5.8377647,
#  'e0cd383fe69129215bbd61ba988989d1f0b63640': 5.011805,
#  '2ba00a2483da994625801da03085e4f621d5bdac': 5.808968,
#  ...}

# %% [markdown]
# #### Model Results for Month 2

# %%
m1 = {**m1, **dict(zip(Z.loc[(Z.month==1),'sku_hash'], test_m1))}
    
oof_m1 = pd.DataFrame.from_dict(m1, orient='index').reset_index()    
oof_m1.columns = ['sku_hash', 'oof_m1']

X2 = pd.merge(X.copy(), oof_m1, on = 'sku_hash')
Z2 = pd.merge(Z.copy(), oof_m1, on = 'sku_hash')
features2 = features + ['oof_m1']

# %%
dtrain2, dval2, dtest2 = train_test_split(tr = X2, te = Z2, mo = 2, feats = features2, num_folds = 5)

model_m2 = []

for i in range(5):
    model_m2.append(
        xgb.train(
                  param,
                  dtrain2[i],
                  50000,
                  [(dtrain2[i],'train'), (dval2[i],'eval')],
                  early_stopping_rounds = 200,
                  verbose_eval = False)
    )

# run predictions for month 2       
    
oof_m2 = []
oof_test_m2 = []
for i in range(5):
    oof_m2.append(model_m2[i].predict(dval2[i]))
    oof_test_m2.append(model_m2[i].predict(dtest2))
    
test_m2 = np.mean(oof_test_m2, axis=0)    
    
m2 = {}
for i in range(5):
    m2 = {**m2, **dict(zip(X.loc[(X.month==2) & (X.idx==i),'sku_hash'], oof_m2[i]))}
    
m2 = {**m2, **dict(zip(Z.loc[(Z.month==2),'sku_hash'], test_m2))}
    
oof_m2 = pd.DataFrame.from_dict(m2, orient='index').reset_index()    
oof_m2.columns = ['sku_hash', 'oof_m2']

X3 = pd.merge(X2.copy(), oof_m2, on = 'sku_hash')
Z3 = pd.merge(Z2.copy(), oof_m2, on = 'sku_hash')
features3 = features2 + ['oof_m2']

# %% [markdown]
# #### Model Results for Month 3

# %%
dtrain3, dval3, dtest3 = train_test_split(tr = X3, te = Z3, mo = 3, feats = features3, num_folds = 5)

model_m3 = []

for i in range(5):
    model_m3.append(
        xgb.train(
                  param,
                  dtrain3[i],
                  50000,
                  [(dtrain3[i],'train'),(dval3[i],'eval')],
                  early_stopping_rounds = 200,
                  verbose_eval = False)
    )

# run predictions for month 3       
    
oof_m3 = []
oof_test_m3 = []
for i in range(5):
    oof_m3.append(model_m3[i].predict(dval3[i]))
    oof_test_m3.append(model_m3[i].predict(dtest3))
    
test_m3 = np.mean(oof_test_m3, axis=0)    
    
m3 = {}
for i in range(5):
    m3 = {**m3, **dict(zip(X.loc[(X.month==3) & (X.idx==i),'sku_hash'], oof_m3[i]))}
    
m3 = {**m3, **dict(zip(Z.loc[(Z.month==3),'sku_hash'], test_m3))}
    
oof_m3 = pd.DataFrame.from_dict(m3, orient='index').reset_index()    
oof_m3.columns = ['sku_hash', 'oof_m3']

X3 = pd.merge(X3.copy(), oof_m3, on = 'sku_hash')
Z3 = pd.merge(Z3.copy(), oof_m3, on = 'sku_hash')

# %% [markdown]
# #### Aggregate the predictions (oof_m1, oof_m2, and oof_m3) into the target and pred_target

# %%
Z3['target'] = 0
Z3.loc[Z3.month == 1, 'target'] = Z3.loc[Z3.month == 1, 'oof_m1'] 
Z3.loc[Z3.month == 2, 'target'] = Z3.loc[Z3.month == 2, 'oof_m2'] 
Z3.loc[Z3.month == 3, 'target'] = Z3.loc[Z3.month == 3, 'oof_m3'] 

X3['pred_target'] = 0
X3.loc[X3.month == 1, 'pred_target'] = X3.loc[X3.month == 1, 'oof_m1'] 
X3.loc[X3.month == 2, 'pred_target'] = X3.loc[X3.month == 2, 'oof_m2'] 
X3.loc[X3.month == 3, 'pred_target'] = X3.loc[X3.month == 3, 'oof_m3']

# %%
Z3['target']
# Out:
# 0       5.703047
# 1       5.695673
# 2       5.455106
# 3       4.480260
# 4       4.273421
#           ...
# 5161    4.469968
# 5162    4.186591
# 5163    5.485417
# 5164    5.256620
# 5165    5.050430
# Name: target, Length: 5166, dtype: float64

# %% [markdown]
# #### Calculate RMSE for different months and an overall RMSE for all months

# %%
print(f"month1: {np.sqrt(np.mean((X3.loc[X3.month==1,'y'] - X3.loc[X3.month==1,'pred_target'])**2))}")
print(f"month2: {np.sqrt(np.mean((X3.loc[X3.month==2,'y'] - X3.loc[X3.month==2,'pred_target'])**2))}")
print(f"month3: {np.sqrt(np.mean((X3.loc[X3.month==3,'y'] - X3.loc[X3.month==3,'pred_target'])**2))}")
print(f"overall: {np.sqrt(np.mean((X3['y'] - X3['pred_target'])**2))}")
# Out:
# month1: 0.44544900509398433
# month2: 0.5822352889936886
# month3: 0.7158942376775735
# overall: 0.5915874991435423

# %% [markdown]
# #### Print prediction results (predicted sales quantity for test data set) after inverse log transformation

# %%
Z3['target'] = np.expm1(Z3['target'])-1 
final_sub = Z3[['ID','target']]
final_sub.to_csv(os.path.join(base_path,'final.csv'),index=None)
final_sub
# Out:
#                                               ID      target
# 0     ed4c7471eac7e8c6e6718364c2b6e75462eeb47c_1  297.779521
# 1     ed4c7471eac7e8c6e6718364c2b6e75462eeb47c_2  295.577134
# 2     ed4c7471eac7e8c6e6718364c2b6e75462eeb47c_3  231.949617
# 3     26b2c4f6281482cccf1e748ef388f1649ecf1c8b_1   86.257607
# 4     26b2c4f6281482cccf1e748ef388f1649ecf1c8b_2   69.766717
# ...                                          ...         ...
# 5161  45a654a8d97c04344dbebc023cb89c55bd6bec77_2   85.353914
# 5162  45a654a8d97c04344dbebc023cb89c55bd6bec77_3   63.798112
# 5163  e0f0364a864880acdf203a035ac63cb0d3d04c97_1  239.149571
# 5164  e0f0364a864880acdf203a035ac63cb0d3d04c97_2  189.832080
# 5165  e0f0364a864880acdf203a035ac63cb0d3d04c97_3  154.089541
#
# [5166 rows x 2 columns]
